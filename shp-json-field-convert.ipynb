# %% [markdown]
# # Shapefile 与 JSON 字段属性映射工具
#
# 本工具用于**将 JSON 接口数据与 Shapefile 进行关联**，根据 ID 字段匹配，提取特定属性（如 systemtype）并生成映射关系。
#
# ## 主要功能
#
# 1. 读取 Shapefile 和 JSON 数据
# 2. 基于 ID 字段进行数据关联（LEFT JOIN）
# 3. 提取并聚合属性信息（如 systemtype）
# 4. 生成序号到属性类型的映射表
# 5. 导出 CSV 和 JSON 格式的映射文件
# 6. 数据质量检查（未匹配项、重复项）
#
# ## 应用场景
#
# - 管线数据与业务系统数据整合
# - 从 API 接口获取的序号数据与 GIS 数据关联
# - 生成数据字典和映射关系文档
# - 数据清洗和质量检查
#
# > **依赖库**
# > - GeoPandas
# > - Pandas
# > - JSON（标准库）
# >
# > 安装命令：
# > ```bash
# > pip install geopandas pandas
# > ```

# %%
# 安装：pip install geopandas pandas shapely pyproj fiona
import json
import pandas as pd
import geopandas as gpd
from pathlib import Path

# ======= 需按实际情况修改的参数 =======
SHP_PATH = r"F:\beipai\管井\0624\84版\links.shp"     # 你的shp路径
SHP_ID_COL = "id"                              # shp里ID字段名
SHP_SYS_COL = "systemtype"                     # shp里systemtype字段名

JSON_PATH = r"F:\beipai\管井\管线管井序号编码\管线.json"       # 接口JSON文件路径
OUTPUT_DIR = r"F:\beipai\管井\管线管井序号编码\links_out"

# %% [markdown]
# ## 1. 配置参数
#
# 设置 Shapefile 路径、JSON 路径、字段名等参数。

# %%
gdf = gpd.read_file(SHP_PATH)  # 如遇编码乱码：gpd.read_file(SHP_PATH, encoding="gbk")
# Out:
# C:\Users\lishuhao\AppData\Local\anaconda3\Lib\site-packages\pyogrio\core.py:35: RuntimeWarning: Could not detect GDAL data files.  Set GDAL_DATA environment variable to the correct path.
#   _init_gdal_data()
# C:\Users\lishuhao\AppData\Local\anaconda3\Lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: One or several characters couldn't be converted correctly from CP936 to UTF-8.  This warning will not be emitted anymore
#   return ogr_read(

# %% [markdown]
# ## 2. 读取 Shapefile

# %%
gdf
# Out:
#                 id asset_id asset_uid  baseheight  bot_rcw  bot_rhw  bot_man  \
# 0        B000016.1  B000016      None           0      1.5      0.0     25.0
# 1        B000017.1  B000017      None           0      1.5      0.0     25.0
# 2        B000018.1  B000018      None           0      1.5      0.0     25.0
# 3        B000020.1  B000020      None           0      1.5      0.0     25.0
# 4        B000197.1  B000233      None           0      1.5      NaN     25.0
# ...            ...      ...       ...         ...      ...      ...      ...
# 245556   S009904.1  S000628      None           0      1.5      NaN     25.0
# 245557   S022178.1  S026285      None           0      1.5      NaN     25.0
# 245558   S022183.1  S026240      None           0      1.5      NaN     25.0
# 245559   S033359.1  S033539      None           0      1.5      NaN     25.0
# 245560  SF_03578.1  S026238      None           0      1.5      NaN     25.0
#
#         bot_n  branch_id  capacity  ...   UT4   UT5   UT6   UT7   UT8   UT9  \
# 0       0.014        NaN     0.722  ...  污水三级  None  None  None  None  None
# 1       0.014        NaN     0.460  ...  污水三级  None  None  None  None  None
# 2       0.014        NaN     1.443  ...  污水三级  None  None  None  None  None
# 3       0.014        NaN     0.105  ...  污水四级  None  None  None  None  None
# 4       0.014        NaN     0.073  ...  污水三级  None  None  None  None  None
# ...       ...        ...       ...  ...   ...   ...   ...   ...   ...   ...
# 245556  0.014        NaN     0.247  ...  污水四级  None  None  None  None  None
# 245557  0.014        NaN     0.299  ...  污水四级  None  None  None  None  None
# 245558  0.014        NaN     0.399  ...  污水五级  None  None  None  None  None
# 245559  0.014        NaN     3.795  ...  污水五级  雨水二级  None  None  None  None
# 245560  0.014        NaN     0.041  ...  污水五级  None  None  None  None  None
#
#        hotlinks  link_shape       gscc  \
# 0          None       round       1500
# 1          None       round       1500
# 2          None       round       1500
# 3          None       round       1000
# 4          None       round       1000
# ...         ...         ...        ...
# 245556     None       round       1000
# 245557     None       round       1000
# 245558     None       round       1000
# 245559     None   rectangle  2200*1700
# 245560     None       round       1000
#
#                                          geometry
# 0       LINESTRING (116.52 39.975, 116.52 39.975)
# 1       LINESTRING (116.52 39.975, 116.52 39.974)
# 2       LINESTRING (116.52 39.974, 116.52 39.974)
# 3       LINESTRING (116.52 39.974, 116.52 39.974)
# 4         LINESTRING (116.6 39.961, 116.6 39.961)
# ...                                           ...
# 245556  LINESTRING (116.32 39.898, 116.32 39.898)
# 245557  LINESTRING (116.32 39.898, 116.32 39.898)
# 245558  LINESTRING (116.32 39.898, 116.32 39.898)
# 245559  LINESTRING (116.32 39.898, 116.32 39.898)
# 245560  LINESTRING (116.32 39.898, 116.32 39.898)
#
# [245561 rows x 80 columns]

# %%
gdf = gpd.read_file(SHP_PATH)                # 如中文乱码可加 encoding="gbk"
gdf[SHP_ID_COL] = gdf[SHP_ID_COL].astype(str)
shp_df = gdf[[SHP_ID_COL, SHP_SYS_COL]].copy()
# Out:
# C:\Users\lishuhao\AppData\Local\anaconda3\Lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: One or several characters couldn't be converted correctly from CP936 to UTF-8.  This warning will not be emitted anymore
#   return ogr_read(

# %% [markdown]
# ## 3. 读取 JSON 数据
#
# JSON 格式要求：顶层包含 `result` 列表。

# %%
# ======= 2) 读取 JSON（含 code/info/result 结构），提取 result 列表 =======
with open(JSON_PATH, "r", encoding="utf-8") as f:
    data = json.load(f)

if not isinstance(data, dict) or "result" not in data:
    raise ValueError("JSON 顶层应为 dict 且包含 'result'。")

result = data["result"]
if not isinstance(result, list):
    raise ValueError("'result' 应为列表。")

# %% [markdown]
# ## 4. 标准化字段名
#
# 将 `arraySequence` 和 `conduitId` 重命名为 `seq` 和 `id`。

# %%
# 标准化为 seq、id 两列（arraySequence -> seq, nodeId -> id）
json_df = pd.DataFrame(result)
required_cols = {"arraySequence", "conduitId"}
missing = required_cols - set(json_df.columns)
if missing:
    raise ValueError(f"result 中缺少字段: {missing}")

json_df = json_df.rename(columns={"arraySequence": "seq", "conduitId": "id"})
# 统一类型，避免 001 与 1 的不一致
json_df["id"] = json_df["id"].astype(str)
# seq 既可保持为整型，也可转字符串；这里保留整型以便排序
# json_df["seq"] = json_df["seq"].astype(str)

# %%
result
# Out:
# [{'conduitId': 'B000016.1', 'arraySequence': 0},
#  {'conduitId': 'B000201.1', 'arraySequence': 1},
#  {'conduitId': 'B011343.1', 'arraySequence': 2},
#  {'conduitId': 'B011363.1', 'arraySequence': 3},
#  {'conduitId': 'B011454.1', 'arraySequence': 4},
#  {'conduitId': 'B011463.1', 'arraySequence': 5},
#  {'conduitId': 'B011487.1', 'arraySequence': 6},
#  {'conduitId': 'B011489.1', 'arraySequence': 7},
#  {'conduitId': 'B011512.1', 'arraySequence': 8},
#  {'conduitId': 'B011513.1', 'arraySequence': 9},
#  {'conduitId': 'B011516.1', 'arraySequence': 10},
#  {'conduitId': 'B011663.1', 'arraySequence': 11},
#  {'conduitId': 'B011664.1', 'arraySequence': 12},
#  {'conduitId': 'B011670.1', 'arraySequence': 13},
#  {'conduitId': 'B011711.1', 'arraySequence': 14},
#  {'conduitId': 'B011712.1', 'arraySequence': 15},
#  {'conduitId': 'B011721.1', 'arraySequence': 16},
#  {'conduitId': 'B011735.1', 'arraySequence': 17},
#  {'conduitId': 'B011745.1', 'arraySequence': 18},
#  {'conduitId': 'B011760.1', 'arraySequence': 19},
#  {'conduitId': 'B011764.1', 'arraySequence': 20},
#  {'conduitId': 'B011796.1', 'arraySequence': 21},
#  {'conduitId': 'B011811.1', 'arraySequence': 22},
#  {'conduitId': 'B011814.1', 'arraySequence': 23},
#  {'conduitId': 'B011854.1', 'arraySequence': 24},
#  {'conduitId': 'B011878.1', 'arraySequence': 25},
#  {'conduitId': 'B011908.1', 'arraySequence': 26},
#  {'conduitId': 'B012187.1', 'arraySequence': 27},
#  {'conduitId': 'B012336.1', 'arraySequence': 28},
#  {'conduitId': 'BH_00006.1', 'arraySequence': 29},
#  {'conduitId': 'BH_00022.1', 'arraySequence': 30},
#  {'conduitId': 'BH_00023.1', 'arraySequence': 31},
#  {'conduitId': 'BH_00024.1', 'arraySequence': 32},
#  {'conduitId': 'BH_00027.1', 'arraySequence': 33},
#  {'conduitId': 'BH_00028.1', 'arraySequence': 34},
#  {'conduitId': 'BH_00029.1', 'arraySequence': 35},
#  {'conduitId': 'BH_00030.1', 'arraySequence': 36},
#  {'conduitId': 'BH_00032.1', 'arraySequence': 37},
#  {'conduitId': 'BH_00033.1', 'arraySequence': 38},
#  {'conduitId': 'BH_00034.1', 'arraySequence': 39},
#  {'conduitId': 'BH_00036.1', 'arraySequence': 40},
#  {'conduitId': 'BH_00038.1', 'arraySequence': 41},
#  {'conduitId': 'BH_00041.1', 'arraySequence': 42},
#  {'conduitId': 'BH_00042.1', 'arraySequence': 43},
#  {'conduitId': 'BH_00044.1', 'arraySequence': 44},
#  {'conduitId': 'BH_00045.1', 'arraySequence': 45},
#  {'conduitId': 'E054799.2', 'arraySequence': 46},
#  {'conduitId': 'BH_00048.1', 'arraySequence': 47},
#  {'conduitId': 'BH_00054.1', 'arraySequence': 48},
#  {'conduitId': 'BH_00055.1', 'arraySequence': 49},
#  {'conduitId': 'BH_00056.1', 'arraySequence': 50},
#  {'conduitId': 'BH_00057.1', 'arraySequence': 51},
#  {'conduitId': 'BH_00059.1', 'arraySequence': 52},
#  {'conduitId': 'BH_00060.1', 'arraySequence': 53},
#  {'conduitId': 'BH_00061.1', 'arraySequence': 54},
#  {'conduitId': 'BH_00062.1', 'arraySequence': 55},
#  {'conduitId': 'BH_00063.1', 'arraySequence': 56},
#  {'conduitId': 'BH_00064.1', 'arraySequence': 57},
#  {'conduitId': 'BH_00065.1', 'arraySequence': 58},
#  {'conduitId': 'BH_00066.1', 'arraySequence': 59},
#  {'conduitId': 'BH_00068.1', 'arraySequence': 60},
#  {'conduitId': 'BH_00069.1', 'arraySequence': 61},
#  {'conduitId': 'BH_00070.1', 'arraySequence': 62},
#  {'conduitId': 'BH_00072.1', 'arraySequence': 63},
#  {'conduitId': 'BH_00073.1', 'arraySequence': 64},
#  {'conduitId': 'BH_00074.1', 'arraySequence': 65},
#  {'conduitId': 'BH_00075.1', 'arraySequence': 66},
#  {'conduitId': 'BH_00076.1', 'arraySequence': 67},
#  {'conduitId': 'BH_00077.1', 'arraySequence': 68},
#  {'conduitId': 'BH_00078.1', 'arraySequence': 69},
#  {'conduitId': 'BH_00079.1', 'arraySequence': 70},
#  {'conduitId': 'BH_00080.1', 'arraySequence': 71},
#  {'conduitId': 'BH_00081.1', 'arraySequence': 72},
#  {'conduitId': 'BH_00082.1', 'arraySequence': 73},
#  {'conduitId': 'BH_00083.1', 'arraySequence': 74},
#  {'conduitId': 'BH_00084.1', 'arraySequence': 75},
#  {'conduitId': 'BH_00087.1', 'arraySequence': 76},
#  {'conduitId': 'BH_00088.1', 'arraySequence': 77},
#  {'conduitId': 'BH_00090.1', 'arraySequence': 78},
#  {'conduitId': 'BH_00092.1', 'arraySequence': 79},
#  {'conduitId': 'BH_00093.1', 'arraySequence': 80},
#  {'conduitId': 'BH_00094.1', 'arraySequence': 81},
#  {'conduitId': 'BH_00095.1', 'arraySequence': 82},
#  {'conduitId': 'BH_00097.1', 'arraySequence': 83},
#  {'conduitId': 'BH_00099.1', 'arraySequence': 84},
#  {'conduitId': 'BH_00103.1', 'arraySequence': 85},
#  {'conduitId': 'BH_00106.1', 'arraySequence': 86},
#  {'conduitId': 'BH_00121.1', 'arraySequence': 87},
#  {'conduitId': 'BH_00125.1', 'arraySequence': 88},
#  {'conduitId': 'BH_00140.1', 'arraySequence': 89},
#  {'conduitId': 'BH_00141.1', 'arraySequence': 90},
#  {'conduitId': 'BH_00142.1', 'arraySequence': 91},
#  {'conduitId': 'BH_00143.1', 'arraySequence': 92},
#  {'conduitId': 'BH_00146.1', 'arraySequence': 93},
#  {'conduitId': 'BH_00159.1', 'arraySequence': 94},
#  {'conduitId': 'BH_00160.1', 'arraySequence': 95},
#  {'conduitId': 'BH_00163.1', 'arraySequence': 96},
#  {'conduitId': 'BH_00164.1', 'arraySequence': 97},
#  {'conduitId': 'BH_00167.1', 'arraySequence': 98},
#  {'conduitId': 'BH_00168.1', 'arraySequence': 99},
#  {'conduitId': 'BH_00169.1', 'arraySequence': 100},
#  {'conduitId': 'BH_00170.1', 'arraySequence': 101},
#  {'conduitId': 'BH_00171.1', 'arraySequence': 102},
#  {'conduitId': 'BH_00172.1', 'arraySequence': 103},
#  {'conduitId': 'BH_00175.1', 'arraySequence': 104},
#  {'conduitId': 'BH_00176.1', 'arraySequence': 105},
#  {'conduitId': 'BH_00185.1', 'arraySequence': 106},
#  {'conduitId': 'BH_00187.1', 'arraySequence': 107},
#  {'conduitId': 'BH_00188.1', 'arraySequence': 108},
#  {'conduitId': 'BH_00190.1', 'arraySequence': 109},
#  {'conduitId': 'BH_00196.1', 'arraySequence': 110},
#  {'conduitId': 'BH_00197.1', 'arraySequence': 111},
#  {'conduitId': 'BH_00199.1', 'arraySequence': 112},
#  {'conduitId': 'BH_00203.1', 'arraySequence': 113},
#  {'conduitId': 'BH_00205.1', 'arraySequence': 114},
#  {'conduitId': 'BH_00207.1', 'arraySequence': 115},
#  {'conduitId': 'BH_00208.1', 'arraySequence': 116},
#  {'conduitId': 'BH_00211.1', 'arraySequence': 117},
#  {'conduitId': 'BH_00212.1', 'arraySequence': 118},
#  {'conduitId': 'BH_00216.1', 'arraySequence': 119},
#  {'conduitId': 'BH_00219.1', 'arraySequence': 120},
#  {'conduitId': 'BH_00223.1', 'arraySequence': 121},
#  {'conduitId': 'BH_00224.1', 'arraySequence': 122},
#  {'conduitId': 'BH_00229.1', 'arraySequence': 123},
#  {'conduitId': 'BH_00230.1', 'arraySequence': 124},
#  {'conduitId': 'BH_00231.1', 'arraySequence': 125},
#  {'conduitId': 'BH_00236.1', 'arraySequence': 126},
#  {'conduitId': 'BH_00238.1', 'arraySequence': 127},
#  {'conduitId': 'BH_00241.1', 'arraySequence': 128},
#  {'conduitId': 'BH_00248.1', 'arraySequence': 129},
#  {'conduitId': 'BH_00251.1', 'arraySequence': 130},
#  {'conduitId': 'BH_00255.1', 'arraySequence': 131},
#  {'conduitId': 'BH_00258.1', 'arraySequence': 132},
#  {'conduitId': 'BH_00260.1', 'arraySequence': 133},
#  {'conduitId': 'BH_00261.1', 'arraySequence': 134},
#  {'conduitId': 'BH_00262.1', 'arraySequence': 135},
#  {'conduitId': 'BH_00263.1', 'arraySequence': 136},
#  {'conduitId': 'BH_00264.1', 'arraySequence': 137},
#  {'conduitId': 'BH_00268.1', 'arraySequence': 138},
#  {'conduitId': 'BH_00271.1', 'arraySequence': 139},
#  {'conduitId': 'BH_00274.1', 'arraySequence': 140},
#  {'conduitId': 'BH_00277.1', 'arraySequence': 141},
#  {'conduitId': 'BH_00283.1', 'arraySequence': 142},
#  {'conduitId': 'BH_00292.1', 'arraySequence': 143},
#  {'conduitId': 'BH_00293.1', 'arraySequence': 144},
#  {'conduitId': 'BH_00298.1', 'arraySequence': 145},
#  {'conduitId': 'BH_00299.1', 'arraySequence': 146},
#  {'conduitId': 'BH_00301.1', 'arraySequence': 147},
#  {'conduitId': 'BH_00304.1', 'arraySequence': 148},
#  {'conduitId': 'BH_00305.1', 'arraySequence': 149},
#  {'conduitId': 'BH_00309.1', 'arraySequence': 150},
#  {'conduitId': 'BH_00310.1', 'arraySequence': 151},
#  {'conduitId': 'BH_00311.1', 'arraySequence': 152},
#  {'conduitId': 'BH_00320.1', 'arraySequence': 153},
#  {'conduitId': 'BH_00321.1', 'arraySequence': 154},
#  {'conduitId': 'BH_00326.1', 'arraySequence': 155},
#  {'conduitId': 'BH_00327.1', 'arraySequence': 156},
#  {'conduitId': 'BH_00328.1', 'arraySequence': 157},
#  {'conduitId': 'BH_00330.1', 'arraySequence': 158},
#  {'conduitId': 'BH_00341.1', 'arraySequence': 159},
#  {'conduitId': 'BH_00345.1', 'arraySequence': 160},
#  {'conduitId': 'BH_00346.1', 'arraySequence': 161},
#  {'conduitId': 'BH_00351.1', 'arraySequence': 162},
#  {'conduitId': 'BH_00352.1', 'arraySequence': 163},
#  {'conduitId': 'BH_00353.1', 'arraySequence': 164},
#  {'conduitId': 'BH_00354.1', 'arraySequence': 165},
#  {'conduitId': 'BH_00356.1', 'arraySequence': 166},
#  {'conduitId': 'BH_00360.2', 'arraySequence': 167},
#  {'conduitId': 'BH_00361.1', 'arraySequence': 168},
#  {'conduitId': 'BH_00362.1', 'arraySequence': 169},
#  {'conduitId': 'BH_00367.1', 'arraySequence': 170},
#  {'conduitId': 'BH_00368.1', 'arraySequence': 171},
#  {'conduitId': 'BH_00369.1', 'arraySequence': 172},
#  {'conduitId': 'BH_00376.1', 'arraySequence': 173},
#  {'conduitId': 'BH_00386.1', 'arraySequence': 174},
#  {'conduitId': 'BH_00390.1', 'arraySequence': 175},
#  {'conduitId': 'BH_00391.1', 'arraySequence': 176},
#  {'conduitId': 'BH_00394.1', 'arraySequence': 177},
#  {'conduitId': 'BH_00395.1', 'arraySequence': 178},
#  {'conduitId': 'BH_00396.2', 'arraySequence': 179},
#  {'conduitId': 'BH_00450.1', 'arraySequence': 180},
#  {'conduitId': 'BH_00456.1', 'arraySequence': 181},
#  {'conduitId': 'BH_00458.1', 'arraySequence': 182},
#  {'conduitId': 'BH_00459.1', 'arraySequence': 183},
#  {'conduitId': 'BH_00463.2', 'arraySequence': 184},
#  {'conduitId': 'BH_00465.1', 'arraySequence': 185},
#  {'conduitId': 'BH_00466.1', 'arraySequence': 186},
#  {'conduitId': 'BH_00478.1', 'arraySequence': 187},
#  {'conduitId': 'BH_00486.1', 'arraySequence': 188},
#  {'conduitId': 'BH_00497.1', 'arraySequence': 189},
#  {'conduitId': 'BH_00509.2', 'arraySequence': 190},
#  {'conduitId': 'BH_00518.1', 'arraySequence': 191},
#  {'conduitId': 'BH_00519.1', 'arraySequence': 192},
#  {'conduitId': 'BH_00521.2', 'arraySequence': 193},
#  {'conduitId': 'BH_00526.2', 'arraySequence': 194},
#  {'conduitId': 'BH_00528.2', 'arraySequence': 195},
#  {'conduitId': 'E091020.1', 'arraySequence': 196},
#  {'conduitId': 'BH_00559.1', 'arraySequence': 197},
#  {'conduitId': 'S100572.1', 'arraySequence': 198},
#  {'conduitId': 'BH_00572.1', 'arraySequence': 199},
#  {'conduitId': 'BH_00616.1', 'arraySequence': 200},
#  {'conduitId': 'BH_00621.1', 'arraySequence': 201},
#  {'conduitId': 'BH_00622.1', 'arraySequence': 202},
#  {'conduitId': 'BH_00623.1', 'arraySequence': 203},
#  {'conduitId': 'BH_00624.1', 'arraySequence': 204},
#  {'conduitId': 'BH_00629.1', 'arraySequence': 205},
#  {'conduitId': 'BH_00631.2', 'arraySequence': 206},
#  {'conduitId': 'BH_00634.1', 'arraySequence': 207},
#  {'conduitId': 'BH_00635.1', 'arraySequence': 208},
#  {'conduitId': 'BH_00636.1', 'arraySequence': 209},
#  {'conduitId': 'BH_00638.1', 'arraySequence': 210},
#  {'conduitId': 'BH_00647.1', 'arraySequence': 211},
#  {'conduitId': 'BH_00648.1', 'arraySequence': 212},
#  {'conduitId': 'BH_00649.1', 'arraySequence': 213},
#  {'conduitId': 'BH_00650.1', 'arraySequence': 214},
#  {'conduitId': 'BH_00651.1', 'arraySequence': 215},
#  {'conduitId': 'BH_00678.1', 'arraySequence': 216},
#  {'conduitId': 'BH_00680.1', 'arraySequence': 217},
#  {'conduitId': 'BH_00681.1', 'arraySequence': 218},
#  {'conduitId': 'BH_00684.1', 'arraySequence': 219},
#  {'conduitId': 'B020207.1', 'arraySequence': 220},
#  {'conduitId': 'BH_00686.1', 'arraySequence': 221},
#  {'conduitId': 'BH_00687.1', 'arraySequence': 222},
#  {'conduitId': 'BH_00688.1', 'arraySequence': 223},
#  {'conduitId': 'BH_00689.1', 'arraySequence': 224},
#  {'conduitId': 'BH_00690.1', 'arraySequence': 225},
#  {'conduitId': 'BH_00691.1', 'arraySequence': 226},
#  {'conduitId': 'BH_00692.1', 'arraySequence': 227},
#  {'conduitId': 'BH_00693.1', 'arraySequence': 228},
#  {'conduitId': 'BH_00694.1', 'arraySequence': 229},
#  {'conduitId': 'BH_00695.1', 'arraySequence': 230},
#  {'conduitId': 'BH_00696.1', 'arraySequence': 231},
#  {'conduitId': 'BH_00697.1', 'arraySequence': 232},
#  {'conduitId': 'BH_00698.1', 'arraySequence': 233},
#  {'conduitId': 'BH_00699.1', 'arraySequence': 234},
#  {'conduitId': 'BH_00701.3', 'arraySequence': 235},
#  {'conduitId': 'BH_00709.1', 'arraySequence': 236},
#  {'conduitId': 'BH_00715.1', 'arraySequence': 237},
#  {'conduitId': 'BH_00728.1', 'arraySequence': 238},
#  {'conduitId': 'BH_00739.1', 'arraySequence': 239},
#  {'conduitId': 'BH_00741.1', 'arraySequence': 240},
#  {'conduitId': 'BH_00794.1', 'arraySequence': 241},
#  {'conduitId': 'BH_00811.1', 'arraySequence': 242},
#  {'conduitId': 'BH_00829.1', 'arraySequence': 243},
#  {'conduitId': 'BH_00860.1', 'arraySequence': 244},
#  {'conduitId': 'BH_00864.1', 'arraySequence': 245},
#  {'conduitId': 'E073420.1', 'arraySequence': 246},
#  {'conduitId': 'B022132.1', 'arraySequence': 247},
#  {'conduitId': 'BH_00899.1', 'arraySequence': 248},
#  {'conduitId': 'BH_00911.1', 'arraySequence': 249},
#  {'conduitId': 'BH_00051.1', 'arraySequence': 250},
#  {'conduitId': 'E007993.1', 'arraySequence': 784},
#  {'conduitId': 'E008101.1', 'arraySequence': 785},
#  {'conduitId': 'E008102.1', 'arraySequence': 786},
#  {'conduitId': 'E008104.1', 'arraySequence': 787},
#  {'conduitId': 'E008111.1', 'arraySequence': 788},
#  {'conduitId': 'E008134.1', 'arraySequence': 789},
#  {'conduitId': 'E008135.2', 'arraySequence': 790},
#  {'conduitId': 'E008136.1', 'arraySequence': 791},
#  {'conduitId': 'E008403.1', 'arraySequence': 792},
#  {'conduitId': 'E008404.1', 'arraySequence': 793},
#  {'conduitId': 'E008414.1', 'arraySequence': 794},
#  {'conduitId': 'E008416.1', 'arraySequence': 795},
#  {'conduitId': 'E008453.1', 'arraySequence': 796},
#  {'conduitId': 'E008669.1', 'arraySequence': 797},
#  {'conduitId': 'E008697.1', 'arraySequence': 798},
#  {'conduitId': 'E008717.1', 'arraySequence': 799},
#  {'conduitId': 'E008780.1', 'arraySequence': 800},
#  {'conduitId': 'E008825.1', 'arraySequence': 801},
#  {'conduitId': 'E009061.1', 'arraySequence': 802},
#  {'conduitId': 'E009062.1', 'arraySequence': 803},
#  {'conduitId': 'E009063.1', 'arraySequence': 804},
#  {'conduitId': 'E009069.1', 'arraySequence': 805},
#  {'conduitId': 'E009070.1', 'arraySequence': 806},
#  {'conduitId': 'E009071.1', 'arraySequence': 807},
#  {'conduitId': 'E009080.1', 'arraySequence': 808},
#  {'conduitId': 'E009164.1', 'arraySequence': 809},
#  {'conduitId': 'E009180.1', 'arraySequence': 810},
#  {'conduitId': 'E009193.1', 'arraySequence': 811},
#  {'conduitId': 'E009201.1', 'arraySequence': 812},
#  {'conduitId': 'E009237.1', 'arraySequence': 813},
#  {'conduitId': 'E009239.1', 'arraySequence': 814},
#  {'conduitId': 'E009240.1', 'arraySequence': 815},
#  {'conduitId': 'E009241.1', 'arraySequence': 816},
#  {'conduitId': 'E009243.1', 'arraySequence': 817},
#  {'conduitId': 'E009244.1', 'arraySequence': 818},
#  {'conduitId': 'E009272.1', 'arraySequence': 819},
#  {'conduitId': 'E009280.1', 'arraySequence': 820},
#  {'conduitId': 'E009281.1', 'arraySequence': 821},
#  {'conduitId': 'E009282.1', 'arraySequence': 822},
#  {'conduitId': 'E009302.1', 'arraySequence': 823},
#  {'conduitId': 'E009305.2', 'arraySequence': 824},
#  {'conduitId': 'E009310.1', 'arraySequence': 825},
#  {'conduitId': 'E009312.1', 'arraySequence': 826},
#  {'conduitId': 'E009328.1', 'arraySequence': 827},
#  {'conduitId': 'E009342.1', 'arraySequence': 828},
#  {'conduitId': 'E009343.1', 'arraySequence': 829},
#  {'conduitId': 'E009345.1', 'arraySequence': 830},
#  {'conduitId': 'E009348.1', 'arraySequence': 831},
#  {'conduitId': 'E009349.1', 'arraySequence': 832},
#  {'conduitId': 'E009352.1', 'arraySequence': 833},
#  {'conduitId': 'E009359.1', 'arraySequence': 834},
#  {'conduitId': 'E009368.1', 'arraySequence': 835},
#  {'conduitId': 'E009382.1', 'arraySequence': 836},
#  {'conduitId': 'E009383.1', 'arraySequence': 837},
#  {'conduitId': 'E009413.1', 'arraySequence': 838},
#  {'conduitId': 'E009413.2', 'arraySequence': 839},
#  {'conduitId': 'E009415.1', 'arraySequence': 840},
#  {'conduitId': 'E009417.1', 'arraySequence': 841},
#  {'conduitId': 'E009425.1', 'arraySequence': 842},
#  {'conduitId': 'E009426.1', 'arraySequence': 843},
#  {'conduitId': 'E009432.1', 'arraySequence': 844},
#  {'conduitId': 'E009438.1', 'arraySequence': 845},
#  {'conduitId': 'E009447.1', 'arraySequence': 846},
#  {'conduitId': 'E009472.1', 'arraySequence': 847},
#  {'conduitId': 'E009481.1', 'arraySequence': 848},
#  {'conduitId': 'E009503.1', 'arraySequence': 849},
#  {'conduitId': 'E009504.1', 'arraySequence': 850},
#  {'conduitId': 'E009733.1', 'arraySequence': 851},
#  {'conduitId': 'E009735.1', 'arraySequence': 852},
#  {'conduitId': 'E009736.1', 'arraySequence': 853},
#  {'conduitId': 'E009737.1', 'arraySequence': 854},
#  {'conduitId': 'E009739.1', 'arraySequence': 855},
#  {'conduitId': 'E009795.1', 'arraySequence': 856},
#  {'conduitId': 'E009829.1', 'arraySequence': 857},
#  {'conduitId': 'E009854.1', 'arraySequence': 858},
#  {'conduitId': 'E009894.1', 'arraySequence': 859},
#  {'conduitId': 'E009896.1', 'arraySequence': 860},
#  {'conduitId': 'E009926.1', 'arraySequence': 861},
#  {'conduitId': 'E009946.1', 'arraySequence': 862},
#  {'conduitId': 'E009954.2', 'arraySequence': 863},
#  {'conduitId': 'E009981.1', 'arraySequence': 864},
#  {'conduitId': 'E010028.1', 'arraySequence': 865},
#  {'conduitId': 'E010030.1', 'arraySequence': 866},
#  {'conduitId': 'E010033.1', 'arraySequence': 867},
#  {'conduitId': 'E010035.1', 'arraySequence': 868},
#  {'conduitId': 'E010054.1', 'arraySequence': 869},
#  {'conduitId': 'E010057.1', 'arraySequence': 870},
#  {'conduitId': 'E010058.1', 'arraySequence': 871},
#  {'conduitId': 'E010103.1', 'arraySequence': 872},
#  {'conduitId': 'E010104.1', 'arraySequence': 873},
#  {'conduitId': 'E010105.1', 'arraySequence': 874},
#  {'conduitId': 'E010129.1', 'arraySequence': 875},
#  {'conduitId': 'E010131.1', 'arraySequence': 876},
#  {'conduitId': 'E010244.1', 'arraySequence': 877},
#  {'conduitId': 'E010295.1', 'arraySequence': 878},
#  {'conduitId': 'E010298.2', 'arraySequence': 879},
#  {'conduitId': 'E010362.1', 'arraySequence': 880},
#  {'conduitId': 'E010364.1', 'arraySequence': 881},
#  {'conduitId': 'E010365.1', 'arraySequence': 882},
#  {'conduitId': 'E010366.1', 'arraySequence': 883},
#  {'conduitId': 'E010367.1', 'arraySequence': 884},
#  {'conduitId': 'E010377.1', 'arraySequence': 885},
#  {'conduitId': 'E010379.1', 'arraySequence': 886},
#  {'conduitId': 'E010380.1', 'arraySequence': 887},
#  {'conduitId': 'E010414.1', 'arraySequence': 888},
#  {'conduitId': 'E010415.1', 'arraySequence': 889},
#  {'conduitId': 'E010416.1', 'arraySequence': 890},
#  {'conduitId': 'E010420.1', 'arraySequence': 891},
#  {'conduitId': 'E010428.1', 'arraySequence': 892},
#  {'conduitId': 'E010431.1', 'arraySequence': 893},
#  {'conduitId': 'E010432.1', 'arraySequence': 894},
#  {'conduitId': 'E010433.1', 'arraySequence': 895},
#  {'conduitId': 'E010434.1', 'arraySequence': 896},
#  {'conduitId': 'E010436.1', 'arraySequence': 897},
#  {'conduitId': 'E010439.2', 'arraySequence': 898},
#  {'conduitId': 'E010451.1', 'arraySequence': 899},
#  {'conduitId': 'E010457.1', 'arraySequence': 900},
#  {'conduitId': 'E010461.1', 'arraySequence': 901},
#  {'conduitId': 'E010486.1', 'arraySequence': 902},
#  {'conduitId': 'E010487.1', 'arraySequence': 903},
#  {'conduitId': 'E010488.1', 'arraySequence': 904},
#  {'conduitId': 'E010532.1', 'arraySequence': 905},
#  {'conduitId': 'E010541.1', 'arraySequence': 906},
#  {'conduitId': 'E010545.1', 'arraySequence': 907},
#  {'conduitId': 'E010551.1', 'arraySequence': 908},
#  {'conduitId': 'E010588.1', 'arraySequence': 909},
#  {'conduitId': 'E010592.1', 'arraySequence': 910},
#  {'conduitId': 'E010593.1', 'arraySequence': 911},
#  {'conduitId': 'E010809.1', 'arraySequence': 912},
#  {'conduitId': 'E010816.1', 'arraySequence': 913},
#  {'conduitId': 'E010817.1', 'arraySequence': 914},
#  {'conduitId': 'E010821.1', 'arraySequence': 915},
#  {'conduitId': 'E010834.1', 'arraySequence': 916},
#  {'conduitId': 'E010836.1', 'arraySequence': 917},
#  {'conduitId': 'E010856.1', 'arraySequence': 918},
#  {'conduitId': 'E010867.1', 'arraySequence': 919},
#  {'conduitId': 'E010945.1', 'arraySequence': 920},
#  {'conduitId': 'E010952.1', 'arraySequence': 921},
#  {'conduitId': 'E010981.1', 'arraySequence': 922},
#  {'conduitId': 'E011081.1', 'arraySequence': 923},
#  {'conduitId': 'E011184.1', 'arraySequence': 924},
#  {'conduitId': 'E011188.1', 'arraySequence': 925},
#  {'conduitId': 'E011231.1', 'arraySequence': 926},
#  {'conduitId': 'E011256.1', 'arraySequence': 927},
#  {'conduitId': 'E011273.1', 'arraySequence': 928},
#  {'conduitId': 'E011332.3', 'arraySequence': 929},
#  {'conduitId': 'E011333.1', 'arraySequence': 930},
#  {'conduitId': 'E011383.1', 'arraySequence': 931},
#  {'conduitId': 'E011384.1', 'arraySequence': 932},
#  {'conduitId': 'E011385.1', 'arraySequence': 933},
#  {'conduitId': 'E011393.1', 'arraySequence': 934},
#  {'conduitId': 'E011395.1', 'arraySequence': 935},
#  {'conduitId': 'E011450.1', 'arraySequence': 936},
#  {'conduitId': 'E011467.1', 'arraySequence': 937},
#  {'conduitId': 'E011515.1', 'arraySequence': 938},
#  {'conduitId': 'E011521.1', 'arraySequence': 939},
#  {'conduitId': 'E011522.1', 'arraySequence': 940},
#  {'conduitId': 'E011524.1', 'arraySequence': 941},
#  {'conduitId': 'E011527.1', 'arraySequence': 942},
#  {'conduitId': 'E011541.1', 'arraySequence': 943},
#  {'conduitId': 'E011549.1', 'arraySequence': 944},
#  {'conduitId': 'E011579.1', 'arraySequence': 945},
#  {'conduitId': 'E011585.1', 'arraySequence': 946},
#  {'conduitId': 'E011599.1', 'arraySequence': 947},
#  {'conduitId': 'E011601.1', 'arraySequence': 948},
#  {'conduitId': 'E011629.1', 'arraySequence': 949},
#  {'conduitId': 'E011668.1', 'arraySequence': 950},
#  {'conduitId': 'E011674.1', 'arraySequence': 951},
#  {'conduitId': 'E011675.1', 'arraySequence': 952},
#  {'conduitId': 'E011676.1', 'arraySequence': 953},
#  {'conduitId': 'E011677.1', 'arraySequence': 954},
#  {'conduitId': 'E011678.1', 'arraySequence': 955},
#  {'conduitId': 'E011686.1', 'arraySequence': 956},
#  {'conduitId': 'E011687.1', 'arraySequence': 957},
#  {'conduitId': 'E011700.1', 'arraySequence': 958},
#  {'conduitId': 'E011701.1', 'arraySequence': 959},
#  {'conduitId': 'E011702.1', 'arraySequence': 960},
#  {'conduitId': 'E011709.1', 'arraySequence': 961},
#  {'conduitId': 'E011710.1', 'arraySequence': 962},
#  {'conduitId': 'E011721.1', 'arraySequence': 963},
#  {'conduitId': 'E011732.1', 'arraySequence': 964},
#  {'conduitId': 'E011733.1', 'arraySequence': 965},
#  {'conduitId': 'E011734.1', 'arraySequence': 966},
#  {'conduitId': 'E011740.2', 'arraySequence': 967},
#  {'conduitId': 'E011755.1', 'arraySequence': 968},
#  {'conduitId': 'E011756.1', 'arraySequence': 969},
#  {'conduitId': 'E011767.1', 'arraySequence': 970},
#  {'conduitId': 'E011768.1', 'arraySequence': 971},
#  {'conduitId': 'E011772.1', 'arraySequence': 972},
#  {'conduitId': 'E011787.1', 'arraySequence': 973},
#  {'conduitId': 'E011796.1', 'arraySequence': 974},
#  {'conduitId': 'E011829.1', 'arraySequence': 975},
#  {'conduitId': 'E011830.1', 'arraySequence': 976},
#  {'conduitId': 'E011831.1', 'arraySequence': 977},
#  {'conduitId': 'E011837.1', 'arraySequence': 978},
#  {'conduitId': 'E011861.1', 'arraySequence': 979},
#  {'conduitId': 'E011862.1', 'arraySequence': 980},
#  {'conduitId': 'E011864.1', 'arraySequence': 981},
#  {'conduitId': 'E011886.1', 'arraySequence': 982},
#  {'conduitId': 'E011888.1', 'arraySequence': 983},
#  {'conduitId': 'E011930.1', 'arraySequence': 984},
#  {'conduitId': 'E011931.1', 'arraySequence': 985},
#  {'conduitId': 'E011957.1', 'arraySequence': 986},
#  {'conduitId': 'E011972.1', 'arraySequence': 987},
#  {'conduitId': 'E011990.1', 'arraySequence': 988},
#  {'conduitId': 'E011994.1', 'arraySequence': 989},
#  {'conduitId': 'E011996.1', 'arraySequence': 990},
#  {'conduitId': 'E012038.1', 'arraySequence': 991},
#  {'conduitId': 'E012084.1', 'arraySequence': 992},
#  {'conduitId': 'E012108.1', 'arraySequence': 993},
#  {'conduitId': 'E012140.1', 'arraySequence': 994},
#  {'conduitId': 'E012150.1', 'arraySequence': 995},
#  {'conduitId': 'E012152.1', 'arraySequence': 996},
#  {'conduitId': 'E012165.1', 'arraySequence': 997},
#  {'conduitId': 'E012166.1', 'arraySequence': 998},
#  {'conduitId': 'E012177.1', 'arraySequence': 999},
#  ...]

# %% [markdown]
# ## 5. 数据关联
#
# 使用 LEFT JOIN 将 JSON 数据与 Shapefile 关联。

# %%
# ======= 3) 关联（以 JSON 为主，LEFT JOIN shp） =======
merged = json_df.merge(shp_df, left_on="id", right_on=SHP_ID_COL, how="left")
merged = merged.drop(columns=[SHP_ID_COL]).rename(columns={SHP_SYS_COL: "systemtype"})

# %% [markdown]
# ## 6. 数据质量检查
#
# 检查匹配率和重复项。

# %%
# ======= 4) 质量检查 =======
not_matched = merged[merged["systemtype"].isna()]
print(f"[INFO] JSON 中序号总数：{len(json_df)}")
print(f"[INFO] 成功匹配到 shp 的条数：{len(merged) - len(not_matched)}")
print(f"[INFO] 未匹配到 shp 的条数：{len(not_matched)}")

# 同一 id 在 shp 是否重复（可能导致一个 seq 对应多个 systemtype）
dup_id = shp_df[shp_df.duplicated(subset=[SHP_ID_COL], keep=False)].sort_values(SHP_ID_COL)
if not dup_id.empty:
    print("[WARN] 下列 id 在 shp 中出现多次（示例前 10 行）：")
    print(dup_id.head(10))
# Out:
# [INFO] JSON 中序号总数：90866
# [INFO] 成功匹配到 shp 的条数：85038
# [INFO] 未匹配到 shp 的条数：5828

# %% [markdown]
# ## 7. 生成映射表
#
# 按序号聚合 systemtype，生成映射关系。

# %%
seq2types = (merged.dropna(subset=["systemtype"])
                   .groupby("seq")["systemtype"]
                   .agg(lambda s: sorted(set(s)))
                   .reset_index())
seq2types_path = str(Path(OUTPUT_DIR, "seq_to_systemtypes.csv"))
seq2types.to_csv(seq2types_path, index=False, encoding="utf-8-sig")
print(f"[DONE] 序号→systemtype 映射：{seq2types_path}")
# Out:
# [DONE] 序号→systemtype 映射：F:\beipai\管井\管线管井序号编码\links_out\seq_to_systemtypes.csv

# %% [markdown]
# ## 8. 导出为 JSON 格式
#
# 便于程序调用的 JSON 格式映射文件。

# %%
import json
from pathlib import Path


# 还是在你已有 seq2types 之后执行
seq2types = (
    merged.dropna(subset=["systemtype"])
          .groupby("seq")["systemtype"]
          .agg(lambda s: sorted(set(s)))
          .reset_index()
)

# 转为 Python dict：{seq: systemtype或[systemtype1, systemtype2,...]}
seq2types_dict = {}
for _, row in seq2types.iterrows():
    seq = int(row["seq"]) if str(row["seq"]).isdigit() else str(row["seq"])
    systems = row["systemtype"]
    # 如果只有一个元素，就直接取字符串而不是列表
    if isinstance(systems, (list, tuple)) and len(systems) == 1:
        seq2types_dict[seq] = systems[0]
    else:
        seq2types_dict[seq] = systems

# %%
# 导出为 JSON 文件
seq2types_path = Path(OUTPUT_DIR) / "seq_to_systemtypes.json"
with open(seq2types_path, "w", encoding="utf-8") as f:
    json.dump(seq2types_dict, f, ensure_ascii=False, indent=2)

print(f"[DONE] 已导出 JSON 文件：{seq2types_path}")
# Out:
# [DONE] 已导出 JSON 文件：F:\beipai\管井\管线管井序号编码\links_out\seq_to_systemtypes.json
