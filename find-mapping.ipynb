# %% [markdown]
# # 管线映射关系挖掘工具
#
# 本工具与 `shp-json-field-convert.ipynb` 功能类似，用于**从 JSON 数据和 Shapefile 中挖掘管线（conduit）的映射关系**。
#
# ## 主要功能
#
# 1. 读取管线 Shapefile 和 JSON 接口数据
# 2. 基于 `asset_id` 字段进行数据关联
# 3. 提取 systemtype（系统类型）属性
# 4. 生成序号（arraySequence）到 systemtype 的映射
# 5. 数据质量检查（匹配率、重复项警告）
# 6. 导出 CSV 和 JSON 格式的映射文件
#
# ## 与 shp-json-field-convert 的区别
#
# - 本工具针对**管线（conduit/link）**数据
# - shp-json-field-convert 针对**管井（node）**数据
# - ID 字段名可能不同（`asset_id` vs `id`）
#
# ## 应用场景
#
# - 管线数据与业务系统整合
# - 系统类型映射表生成
# - 数据完整性检查
# - 多系统数据关联（污水、雨水、合流等）
#
# > **依赖库**
# > - GeoPandas
# > - Pandas
# > - JSON（标准库）
# >
# > 安装命令：
# > ```bash
# > pip install geopandas pandas
# > ```

# %%
# 安装：pip install geopandas pandas shapely pyproj fiona
import json
import pandas as pd
import geopandas as gpd
from pathlib import Path

# ======= 需按实际情况修改的参数 =======
SHP_PATH = r"F:\beipai\管井\0624\84版\links.shp"     # 你的shp路径
SHP_ID_COL = "asset_id"                              # shp里ID字段名
SHP_SYS_COL = "systemtype"                     # shp里systemtype字段名

JSON_PATH = r"F:\beipai\管井\管线管井序号编码\pipe.json"       # 接口JSON文件路径
OUTPUT_DIR = r"F:\beipai\管井\管线管井序号编码\links_out"

# %% [markdown]
# ## 1. 配置参数
#
# 设置 Shapefile 路径、JSON 路径、字段名等。

# %%
gdf = gpd.read_file(SHP_PATH)  # 如遇编码乱码：gpd.read_file(SHP_PATH, encoding="gbk")
# Out:
# C:\Users\lishuhao\AppData\Local\anaconda3\Lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: One or several characters couldn't be converted correctly from CP936 to UTF-8.  This warning will not be emitted anymore
#   return ogr_read(

# %% [markdown]
# ## 2. 读取 Shapefile

# %%
gdf
# Out:
#                 id asset_id asset_uid  baseheight  bot_rcw  bot_rhw  bot_man  \
# 0        B000016.1  B000016      None           0      1.5      0.0     25.0
# 1        B000017.1  B000017      None           0      1.5      0.0     25.0
# 2        B000018.1  B000018      None           0      1.5      0.0     25.0
# 3        B000020.1  B000020      None           0      1.5      0.0     25.0
# 4        B000197.1  B000233      None           0      1.5      NaN     25.0
# ...            ...      ...       ...         ...      ...      ...      ...
# 245556   S009904.1  S000628      None           0      1.5      NaN     25.0
# 245557   S022178.1  S026285      None           0      1.5      NaN     25.0
# 245558   S022183.1  S026240      None           0      1.5      NaN     25.0
# 245559   S033359.1  S033539      None           0      1.5      NaN     25.0
# 245560  SF_03578.1  S026238      None           0      1.5      NaN     25.0
#
#         bot_n  branch_id  capacity  ...   UT4   UT5   UT6   UT7   UT8   UT9  \
# 0       0.014        NaN     0.722  ...  污水三级  None  None  None  None  None
# 1       0.014        NaN     0.460  ...  污水三级  None  None  None  None  None
# 2       0.014        NaN     1.443  ...  污水三级  None  None  None  None  None
# 3       0.014        NaN     0.105  ...  污水四级  None  None  None  None  None
# 4       0.014        NaN     0.073  ...  污水三级  None  None  None  None  None
# ...       ...        ...       ...  ...   ...   ...   ...   ...   ...   ...
# 245556  0.014        NaN     0.247  ...  污水四级  None  None  None  None  None
# 245557  0.014        NaN     0.299  ...  污水四级  None  None  None  None  None
# 245558  0.014        NaN     0.399  ...  污水五级  None  None  None  None  None
# 245559  0.014        NaN     3.795  ...  污水五级  雨水二级  None  None  None  None
# 245560  0.014        NaN     0.041  ...  污水五级  None  None  None  None  None
#
#        hotlinks  link_shape       gscc  \
# 0          None       round       1500
# 1          None       round       1500
# 2          None       round       1500
# 3          None       round       1000
# 4          None       round       1000
# ...         ...         ...        ...
# 245556     None       round       1000
# 245557     None       round       1000
# 245558     None       round       1000
# 245559     None   rectangle  2200*1700
# 245560     None       round       1000
#
#                                          geometry
# 0       LINESTRING (116.52 39.975, 116.52 39.975)
# 1       LINESTRING (116.52 39.975, 116.52 39.974)
# 2       LINESTRING (116.52 39.974, 116.52 39.974)
# 3       LINESTRING (116.52 39.974, 116.52 39.974)
# 4         LINESTRING (116.6 39.961, 116.6 39.961)
# ...                                           ...
# 245556  LINESTRING (116.32 39.898, 116.32 39.898)
# 245557  LINESTRING (116.32 39.898, 116.32 39.898)
# 245558  LINESTRING (116.32 39.898, 116.32 39.898)
# 245559  LINESTRING (116.32 39.898, 116.32 39.898)
# 245560  LINESTRING (116.32 39.898, 116.32 39.898)
#
# [245561 rows x 80 columns]

# %%
gdf = gpd.read_file(SHP_PATH)                # 如中文乱码可加 encoding="gbk"
gdf[SHP_ID_COL] = gdf[SHP_ID_COL].astype(str)
shp_df = gdf[[SHP_ID_COL, SHP_SYS_COL]].copy()
# Out:
# C:\Users\lishuhao\AppData\Local\anaconda3\Lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: One or several characters couldn't be converted correctly from CP936 to UTF-8.  This warning will not be emitted anymore
#   return ogr_read(

# %% [markdown]
# ## 3. 读取 JSON 数据

# %%
# ======= 2) 读取 JSON（含 code/info/result 结构），提取 result 列表 =======
with open(JSON_PATH, "r", encoding="utf-8") as f:
    data = json.load(f)

if not isinstance(data, dict) or "result" not in data:
    raise ValueError("JSON 顶层应为 dict 且包含 'result'。")

result = data["result"]
if not isinstance(result, list):
    raise ValueError("'result' 应为列表。")

# %% [markdown]
# ## 4. 标准化字段名

# %%
# 标准化为 seq、id 两列（arraySequence -> seq, nodeId -> id）
json_df = pd.DataFrame(result)
required_cols = {"arraySequence", "conduitId"}
missing = required_cols - set(json_df.columns)
if missing:
    raise ValueError(f"result 中缺少字段: {missing}")

json_df = json_df.rename(columns={"arraySequence": "seq", "conduitId": "id"})
# 统一类型，避免 001 与 1 的不一致
json_df["id"] = json_df["id"].astype(str)
# seq 既可保持为整型，也可转字符串；这里保留整型以便排序
# json_df["seq"] = json_df["seq"].astype(str)

# %%
result
# Out:
# [{'conduitId': '沈家坟干渠_2', 'arraySequence': '0'},
#  {'conduitId': '沈家坟干渠_3', 'arraySequence': '1'},
#  {'conduitId': '沈家坟干渠_4', 'arraySequence': '2'},
#  {'conduitId': '沈家坟干渠_5', 'arraySequence': '3'},
#  {'conduitId': '沈家坟干渠_6', 'arraySequence': '4'},
#  {'conduitId': '沈家坟干渠_7', 'arraySequence': '5'},
#  {'conduitId': '沈家坟干渠_8', 'arraySequence': '6'},
#  {'conduitId': '沈家坟干渠_9', 'arraySequence': '7'},
#  {'conduitId': '沈家坟干渠_10', 'arraySequence': '8'},
#  {'conduitId': '沈家坟干渠_11', 'arraySequence': '9'},
#  {'conduitId': '沈家坟干渠_12', 'arraySequence': '10'},
#  {'conduitId': '沈家坟干渠_13', 'arraySequence': '11'},
#  {'conduitId': '沈家坟干渠_14', 'arraySequence': '12'},
#  {'conduitId': '沈家坟干渠_15', 'arraySequence': '13'},
#  {'conduitId': '沈家坟干渠_16', 'arraySequence': '14'},
#  {'conduitId': '沈家坟干渠_17', 'arraySequence': '15'},
#  {'conduitId': '沈家坟干渠_18', 'arraySequence': '16'},
#  {'conduitId': '沈家坟干渠_19', 'arraySequence': '17'},
#  {'conduitId': '沈家坟干渠_20', 'arraySequence': '18'},
#  {'conduitId': '沈家坟干渠_21', 'arraySequence': '19'},
#  {'conduitId': '沈家坟干渠_22', 'arraySequence': '20'},
#  {'conduitId': '西干沟_0', 'arraySequence': '21'},
#  {'conduitId': '西干沟_1', 'arraySequence': '22'},
#  {'conduitId': '西干沟_2', 'arraySequence': '23'},
#  {'conduitId': '西干沟_3', 'arraySequence': '24'},
#  {'conduitId': '西干沟_4', 'arraySequence': '25'},
#  {'conduitId': '西干沟_5', 'arraySequence': '26'},
#  {'conduitId': '西干沟_6', 'arraySequence': '27'},
#  {'conduitId': '西干沟_7', 'arraySequence': '28'},
#  {'conduitId': '西干沟_8', 'arraySequence': '29'},
#  {'conduitId': '西干沟_9', 'arraySequence': '30'},
#  {'conduitId': '西干沟_10', 'arraySequence': '31'},
#  {'conduitId': '西干沟_11', 'arraySequence': '32'},
#  {'conduitId': '西干沟_12', 'arraySequence': '33'},
#  {'conduitId': '西干沟_13', 'arraySequence': '34'},
#  {'conduitId': '西干沟_14', 'arraySequence': '35'},
#  {'conduitId': '西干沟_15', 'arraySequence': '36'},
#  {'conduitId': '西干沟_16', 'arraySequence': '37'},
#  {'conduitId': '西干沟_17', 'arraySequence': '38'},
#  {'conduitId': '西干沟_18', 'arraySequence': '39'},
#  {'conduitId': '西干沟_19', 'arraySequence': '40'},
#  {'conduitId': '西干沟_20', 'arraySequence': '41'},
#  {'conduitId': '西干沟_21', 'arraySequence': '42'},
#  {'conduitId': '西干沟_22', 'arraySequence': '43'},
#  {'conduitId': '西干沟_23', 'arraySequence': '44'},
#  {'conduitId': '北小河_0', 'arraySequence': '45'},
#  {'conduitId': '北小河_4', 'arraySequence': '46'},
#  {'conduitId': '北小河_6', 'arraySequence': '47'},
#  {'conduitId': '北小河_8', 'arraySequence': '48'},
#  {'conduitId': '北小河_9', 'arraySequence': '49'},
#  {'conduitId': '北小河_11', 'arraySequence': '50'},
#  {'conduitId': '北小河_12', 'arraySequence': '51'},
#  {'conduitId': '北小河_13', 'arraySequence': '52'},
#  {'conduitId': '北小河_15', 'arraySequence': '53'},
#  {'conduitId': '北小河_16', 'arraySequence': '54'},
#  {'conduitId': '北小河_19', 'arraySequence': '55'},
#  {'conduitId': '北小河_20', 'arraySequence': '56'},
#  {'conduitId': '北小河_21', 'arraySequence': '57'},
#  {'conduitId': '北小河_22', 'arraySequence': '58'},
#  {'conduitId': '北小河_24', 'arraySequence': '59'},
#  {'conduitId': '北小河_25', 'arraySequence': '60'},
#  {'conduitId': '北小河_26', 'arraySequence': '61'},
#  {'conduitId': '北小河_27', 'arraySequence': '62'},
#  {'conduitId': '北小河_29', 'arraySequence': '63'},
#  {'conduitId': '北小河_30', 'arraySequence': '64'},
#  {'conduitId': '北小河_31', 'arraySequence': '65'},
#  {'conduitId': '北小河_32', 'arraySequence': '66'},
#  {'conduitId': '北小河_33', 'arraySequence': '67'},
#  {'conduitId': '北小河_34', 'arraySequence': '68'},
#  {'conduitId': '北小河_36', 'arraySequence': '69'},
#  {'conduitId': '北小河_37', 'arraySequence': '70'},
#  {'conduitId': '萧太后_0', 'arraySequence': '71'},
#  {'conduitId': '萧太后_3', 'arraySequence': '72'},
#  {'conduitId': '萧太后_9', 'arraySequence': '73'},
#  {'conduitId': '萧太后_10', 'arraySequence': '74'},
#  {'conduitId': '萧太后_11', 'arraySequence': '75'},
#  {'conduitId': '萧太后_14', 'arraySequence': '76'},
#  {'conduitId': '萧太后_17', 'arraySequence': '77'},
#  {'conduitId': '萧太后_18', 'arraySequence': '78'},
#  {'conduitId': '萧太后_19', 'arraySequence': '79'},
#  {'conduitId': '萧太后_20', 'arraySequence': '80'},
#  {'conduitId': '萧太后_21', 'arraySequence': '81'},
#  {'conduitId': '萧太后_22', 'arraySequence': '82'},
#  {'conduitId': '萧太后_24', 'arraySequence': '83'},
#  {'conduitId': '萧太后_25', 'arraySequence': '84'},
#  {'conduitId': '萧太后_26', 'arraySequence': '85'},
#  {'conduitId': '萧太后_27', 'arraySequence': '86'},
#  {'conduitId': '通惠排干_0', 'arraySequence': '87'},
#  {'conduitId': '通惠排干_1', 'arraySequence': '88'},
#  {'conduitId': '通惠排干_4', 'arraySequence': '89'},
#  {'conduitId': '通惠排干_5', 'arraySequence': '90'},
#  {'conduitId': '通惠排干_6', 'arraySequence': '91'},
#  {'conduitId': '通惠排干_8', 'arraySequence': '92'},
#  {'conduitId': '大柳树沟_0', 'arraySequence': '93'},
#  {'conduitId': '大柳树沟_1', 'arraySequence': '94'},
#  {'conduitId': '大柳树沟_2', 'arraySequence': '95'},
#  {'conduitId': '大柳树沟_3', 'arraySequence': '96'},
#  {'conduitId': '大柳树沟_4', 'arraySequence': '97'},
#  {'conduitId': '大柳树沟_5', 'arraySequence': '98'},
#  {'conduitId': '大柳树沟_6', 'arraySequence': '99'},
#  {'conduitId': '大柳树沟_7', 'arraySequence': '100'},
#  {'conduitId': '大柳树沟_8', 'arraySequence': '101'},
#  {'conduitId': '大柳树沟_9', 'arraySequence': '102'},
#  {'conduitId': '大柳树沟_10', 'arraySequence': '103'},
#  {'conduitId': '大柳树沟_12', 'arraySequence': '104'},
#  {'conduitId': '大柳树沟_13', 'arraySequence': '105'},
#  {'conduitId': '大柳树沟_14', 'arraySequence': '106'},
#  {'conduitId': '大柳树沟_15', 'arraySequence': '107'},
#  {'conduitId': '大柳树沟_16', 'arraySequence': '108'},
#  {'conduitId': '望京沟_2', 'arraySequence': '109'},
#  {'conduitId': '望京沟_4', 'arraySequence': '110'},
#  {'conduitId': '望京沟_6', 'arraySequence': '111'},
#  {'conduitId': '望京沟_9', 'arraySequence': '112'},
#  {'conduitId': '望京沟_10', 'arraySequence': '113'},
#  {'conduitId': '通惠灌渠_0', 'arraySequence': '114'},
#  {'conduitId': '通惠灌渠_1', 'arraySequence': '115'},
#  {'conduitId': '通惠灌渠_2', 'arraySequence': '116'},
#  {'conduitId': '通惠灌渠_3', 'arraySequence': '117'},
#  {'conduitId': '通惠灌渠_4', 'arraySequence': '118'},
#  {'conduitId': '通惠灌渠_5', 'arraySequence': '119'},
#  {'conduitId': '通惠灌渠_6', 'arraySequence': '120'},
#  {'conduitId': '通惠灌渠_7', 'arraySequence': '121'},
#  {'conduitId': '通惠灌渠_8', 'arraySequence': '122'},
#  {'conduitId': '通惠灌渠_9', 'arraySequence': '123'},
#  {'conduitId': '坝河_0', 'arraySequence': '124'},
#  {'conduitId': '坝河_1', 'arraySequence': '125'},
#  {'conduitId': '坝河_2', 'arraySequence': '126'},
#  {'conduitId': '坝河_3', 'arraySequence': '127'},
#  {'conduitId': '坝河_4', 'arraySequence': '128'},
#  {'conduitId': '坝河_5', 'arraySequence': '129'},
#  {'conduitId': '坝河_6', 'arraySequence': '130'},
#  {'conduitId': '坝河_7', 'arraySequence': '131'},
#  {'conduitId': '坝河_11', 'arraySequence': '132'},
#  {'conduitId': '坝河_13', 'arraySequence': '133'},
#  {'conduitId': '坝河_20', 'arraySequence': '134'},
#  {'conduitId': '坝河_24', 'arraySequence': '135'},
#  {'conduitId': '坝河_25', 'arraySequence': '136'},
#  {'conduitId': '坝河_26', 'arraySequence': '137'},
#  {'conduitId': '坝河_27', 'arraySequence': '138'},
#  {'conduitId': '坝河_28', 'arraySequence': '139'},
#  {'conduitId': '坝河_30', 'arraySequence': '140'},
#  {'conduitId': '坝河_31', 'arraySequence': '141'},
#  {'conduitId': '坝河_33', 'arraySequence': '142'},
#  {'conduitId': '坝河_34', 'arraySequence': '143'},
#  {'conduitId': '坝河_35', 'arraySequence': '144'},
#  {'conduitId': '坝河_36', 'arraySequence': '145'},
#  {'conduitId': '坝河_37', 'arraySequence': '146'},
#  {'conduitId': '坝河_38', 'arraySequence': '147'},
#  {'conduitId': '坝河_40', 'arraySequence': '148'},
#  {'conduitId': '坝河_41', 'arraySequence': '149'},
#  {'conduitId': '坝河_42', 'arraySequence': '150'},
#  {'conduitId': '坝河_43', 'arraySequence': '151'},
#  {'conduitId': '坝河_45', 'arraySequence': '152'},
#  {'conduitId': '坝河_46', 'arraySequence': '153'},
#  {'conduitId': '坝河_47', 'arraySequence': '154'},
#  {'conduitId': '坝河_48', 'arraySequence': '155'},
#  {'conduitId': '坝河_49', 'arraySequence': '156'},
#  {'conduitId': '坝河_50', 'arraySequence': '157'},
#  {'conduitId': '坝河_51', 'arraySequence': '158'},
#  {'conduitId': '坝河_52', 'arraySequence': '159'},
#  {'conduitId': '亮马河下游_0', 'arraySequence': '160'},
#  {'conduitId': '亮马河下游_3', 'arraySequence': '161'},
#  {'conduitId': '亮马河下游_7', 'arraySequence': '162'},
#  {'conduitId': '亮马河下游_8', 'arraySequence': '163'},
#  {'conduitId': '亮马河下游_9', 'arraySequence': '164'},
#  {'conduitId': '亮马河下游_11', 'arraySequence': '165'},
#  {'conduitId': '亮马河下游_12', 'arraySequence': '166'},
#  {'conduitId': '通惠河_5', 'arraySequence': '167'},
#  {'conduitId': '通惠河_8', 'arraySequence': '168'},
#  {'conduitId': '通惠河_10', 'arraySequence': '169'},
#  {'conduitId': '通惠河_11', 'arraySequence': '170'},
#  {'conduitId': '通惠河_13', 'arraySequence': '171'},
#  {'conduitId': '通惠河_15', 'arraySequence': '172'},
#  {'conduitId': '通惠河_16', 'arraySequence': '173'},
#  {'conduitId': '通惠河_19', 'arraySequence': '174'},
#  {'conduitId': '通惠河_23', 'arraySequence': '175'},
#  {'conduitId': '通惠河_24', 'arraySequence': '176'},
#  {'conduitId': '通惠河_25', 'arraySequence': '177'},
#  {'conduitId': '通惠河_26', 'arraySequence': '178'},
#  {'conduitId': '通惠河_27', 'arraySequence': '179'},
#  {'conduitId': '通惠河_32', 'arraySequence': '180'},
#  {'conduitId': '通惠河_33', 'arraySequence': '181'},
#  {'conduitId': '通惠河_36', 'arraySequence': '182'},
#  {'conduitId': '通惠河_37', 'arraySequence': '183'},
#  {'conduitId': '通惠河_41', 'arraySequence': '184'},
#  {'conduitId': '通惠河_42', 'arraySequence': '185'},
#  {'conduitId': '通惠河_43', 'arraySequence': '186'},
#  {'conduitId': '通惠河_44', 'arraySequence': '187'},
#  {'conduitId': '通惠河_45', 'arraySequence': '188'},
#  {'conduitId': '通惠河_49', 'arraySequence': '189'},
#  {'conduitId': '通惠河_50', 'arraySequence': '190'},
#  {'conduitId': '通惠河_52', 'arraySequence': '191'},
#  {'conduitId': '通惠河_53', 'arraySequence': '192'},
#  {'conduitId': '通惠河_54', 'arraySequence': '193'},
#  {'conduitId': '通惠河_55', 'arraySequence': '194'},
#  {'conduitId': '通惠河_56', 'arraySequence': '195'},
#  {'conduitId': '通惠河_57', 'arraySequence': '196'},
#  {'conduitId': '永定河渠_26', 'arraySequence': '248'},
#  {'conduitId': '永定河渠_28', 'arraySequence': '249'},
#  {'conduitId': '永定河渠_29', 'arraySequence': '250'},
#  {'conduitId': '永定河渠_30', 'arraySequence': '251'},
#  {'conduitId': '永定河渠_33', 'arraySequence': '252'},
#  {'conduitId': '永定河渠_34', 'arraySequence': '253'},
#  {'conduitId': '永定河渠_35', 'arraySequence': '254'},
#  {'conduitId': '永定河渠_36', 'arraySequence': '255'},
#  {'conduitId': '永定河渠_40', 'arraySequence': '256'},
#  {'conduitId': '永定河渠_45', 'arraySequence': '257'},
#  {'conduitId': '西护城河_2', 'arraySequence': '258'},
#  {'conduitId': '西护城河_5', 'arraySequence': '259'},
#  {'conduitId': '南护城河_1', 'arraySequence': '260'},
#  {'conduitId': '南护城河_2', 'arraySequence': '261'},
#  {'conduitId': '南护城河_7', 'arraySequence': '262'},
#  {'conduitId': '南护城河_15', 'arraySequence': '263'},
#  {'conduitId': '南护城河_18', 'arraySequence': '264'},
#  {'conduitId': '京密引水渠1_0', 'arraySequence': '265'},
#  {'conduitId': '京密引水渠1_1', 'arraySequence': '266'},
#  {'conduitId': '京密引水渠1_2', 'arraySequence': '267'},
#  {'conduitId': '京密引水渠1_3', 'arraySequence': '268'},
#  {'conduitId': '京密引水渠1_4', 'arraySequence': '269'},
#  {'conduitId': '京密引水渠1_5', 'arraySequence': '270'},
#  {'conduitId': '京密引水渠1_6', 'arraySequence': '271'},
#  {'conduitId': '京密引水渠1_7', 'arraySequence': '272'},
#  {'conduitId': '京密引水渠1_8', 'arraySequence': '273'},
#  {'conduitId': '京密引水渠1_9', 'arraySequence': '274'},
#  {'conduitId': '京密引水渠1_10', 'arraySequence': '275'},
#  {'conduitId': '京密引水渠1_11', 'arraySequence': '276'},
#  {'conduitId': '京密引水渠1_12', 'arraySequence': '277'},
#  {'conduitId': '京密引水渠1_13', 'arraySequence': '278'},
#  {'conduitId': '京密引水渠1_14', 'arraySequence': '279'},
#  {'conduitId': '京密引水渠1_15', 'arraySequence': '280'},
#  {'conduitId': '京密引水渠1_16', 'arraySequence': '281'},
#  {'conduitId': '京密引水渠1_17', 'arraySequence': '282'},
#  {'conduitId': '京密引水渠2_1', 'arraySequence': '283'},
#  {'conduitId': '京密引水渠2_2', 'arraySequence': '284'},
#  {'conduitId': '京密引水渠2_3', 'arraySequence': '285'},
#  {'conduitId': '京密引水渠2_4', 'arraySequence': '286'},
#  {'conduitId': '京密引水渠2_7', 'arraySequence': '287'},
#  {'conduitId': '京密引水渠2_8', 'arraySequence': '288'},
#  {'conduitId': '京密引水渠2_10', 'arraySequence': '289'},
#  {'conduitId': '京密引水渠2_12', 'arraySequence': '290'},
#  {'conduitId': '京密引水渠2_14', 'arraySequence': '291'},
#  {'conduitId': '京密引水渠2_15', 'arraySequence': '292'},
#  {'conduitId': '京密引水渠2_18', 'arraySequence': '293'},
#  {'conduitId': '京密引水渠2_21', 'arraySequence': '294'},
#  {'conduitId': '沈干七支渠_1', 'arraySequence': '593'},
#  {'conduitId': '沈干七支渠_2', 'arraySequence': '594'},
#  {'conduitId': '沈干七支渠_3', 'arraySequence': '595'},
#  {'conduitId': '沈干七支渠_4', 'arraySequence': '596'},
#  {'conduitId': '沈干七支渠_5', 'arraySequence': '597'},
#  {'conduitId': '沈干七支渠_6', 'arraySequence': '598'},
#  {'conduitId': '沈干七支渠_7', 'arraySequence': '599'},
#  {'conduitId': '沈干七支渠_8', 'arraySequence': '600'},
#  {'conduitId': '沈干七支渠_9', 'arraySequence': '601'},
#  {'conduitId': '沈干七支渠_10', 'arraySequence': '602'},
#  {'conduitId': '沈干七支渠_11', 'arraySequence': '603'},
#  {'conduitId': '沈干七支渠_12', 'arraySequence': '604'},
#  {'conduitId': '沈干七支渠_13', 'arraySequence': '605'},
#  {'conduitId': '沈干七支渠_14', 'arraySequence': '606'},
#  {'conduitId': '沈干七支渠_15', 'arraySequence': '607'},
#  {'conduitId': '沈干七支渠_16', 'arraySequence': '608'},
#  {'conduitId': '沈干七支渠_17', 'arraySequence': '609'},
#  {'conduitId': '沈干七支渠_18', 'arraySequence': '610'},
#  {'conduitId': '沈干七支渠_19', 'arraySequence': '611'},
#  {'conduitId': '沈干七支渠_20', 'arraySequence': '612'},
#  {'conduitId': '沈干七支渠_21', 'arraySequence': '613'},
#  {'conduitId': '沈干七支渠_22', 'arraySequence': '614'},
#  {'conduitId': '沈干七支渠_23', 'arraySequence': '615'},
#  {'conduitId': '曹各庄地形_0', 'arraySequence': '616'},
#  {'conduitId': '曹各庄地形_1', 'arraySequence': '617'},
#  {'conduitId': '曹各庄地形_2', 'arraySequence': '618'},
#  {'conduitId': '曹各庄地形_3', 'arraySequence': '619'},
#  {'conduitId': '曹各庄地形_4', 'arraySequence': '620'},
#  {'conduitId': '曹各庄地形_5', 'arraySequence': '621'},
#  {'conduitId': '曹各庄地形_6', 'arraySequence': '622'},
#  {'conduitId': '曹各庄地形_8', 'arraySequence': '623'},
#  {'conduitId': '转河_2', 'arraySequence': '624'},
#  {'conduitId': '转河_3', 'arraySequence': '625'},
#  {'conduitId': '转河_4', 'arraySequence': '626'},
#  {'conduitId': '转河_5', 'arraySequence': '627'},
#  {'conduitId': '转河_7', 'arraySequence': '628'},
#  {'conduitId': '转河_8', 'arraySequence': '629'},
#  {'conduitId': '东直门灌渠上游_1', 'arraySequence': '630'},
#  {'conduitId': '东直门灌渠上游_2', 'arraySequence': '631'},
#  {'conduitId': '东直门灌渠上游_3', 'arraySequence': '632'},
#  {'conduitId': '东直门灌渠上游_4', 'arraySequence': '633'},
#  {'conduitId': '常营中心沟_0', 'arraySequence': '634'},
#  {'conduitId': '通惠河干渠_0', 'arraySequence': '635'},
#  {'conduitId': '通惠河干渠_1', 'arraySequence': '636'},
#  {'conduitId': '通惠河干渠_2', 'arraySequence': '637'},
#  {'conduitId': '通惠河干渠_3', 'arraySequence': '638'},
#  {'conduitId': '通惠河干渠_4', 'arraySequence': '639'},
#  {'conduitId': '通惠河干渠_5', 'arraySequence': '640'},
#  {'conduitId': '通惠河干渠_6', 'arraySequence': '641'},
#  {'conduitId': '通惠河干渠_7', 'arraySequence': '642'},
#  {'conduitId': '通惠河干渠_8', 'arraySequence': '643'},
#  {'conduitId': '通惠河干渠_9', 'arraySequence': '644'},
#  {'conduitId': '通惠河干渠_10', 'arraySequence': '645'},
#  {'conduitId': '通惠河干渠_11', 'arraySequence': '646'},
#  {'conduitId': '通惠河干渠_12', 'arraySequence': '647'},
#  {'conduitId': '小场沟_1', 'arraySequence': '648'},
#  {'conduitId': '小场沟_2', 'arraySequence': '649'},
#  {'conduitId': '小场沟_3', 'arraySequence': '650'},
#  {'conduitId': '小场沟_4', 'arraySequence': '651'},
#  {'conduitId': '小场沟_5', 'arraySequence': '652'},
#  {'conduitId': '小场沟_7', 'arraySequence': '653'},
#  {'conduitId': '小场沟_8', 'arraySequence': '654'},
#  {'conduitId': '小场沟_9', 'arraySequence': '655'},
#  {'conduitId': '小场沟_11', 'arraySequence': '656'},
#  {'conduitId': '小场沟_12', 'arraySequence': '657'},
#  {'conduitId': '小场沟_13', 'arraySequence': '658'},
#  {'conduitId': '小场沟_14', 'arraySequence': '659'},
#  {'conduitId': '小场沟_15', 'arraySequence': '660'},
#  {'conduitId': '小场沟_17', 'arraySequence': '661'},
#  {'conduitId': '小场沟_18', 'arraySequence': '662'},
#  {'conduitId': '小场沟_19', 'arraySequence': '663'},
#  {'conduitId': '小场沟_20', 'arraySequence': '664'},
#  {'conduitId': '小场沟_21', 'arraySequence': '665'},
#  {'conduitId': '小场沟_22', 'arraySequence': '666'},
#  {'conduitId': '小场沟_23', 'arraySequence': '667'},
#  {'conduitId': '小场沟_24', 'arraySequence': '668'},
#  {'conduitId': 'AR-NO20231012163040-P', 'arraySequence': '669'},
#  {'conduitId': 'AR-NO20231012163131-SP', 'arraySequence': '670'},
#  {'conduitId': 'AR-NO20231012163131-EP', 'arraySequence': '671'},
#  {'conduitId': 'AR-NO20231012163138-P', 'arraySequence': '672'},
#  {'conduitId': 'AR-NO20231012163413-P', 'arraySequence': '673'},
#  {'conduitId': 'AR-NO20231012163459-SP', 'arraySequence': '674'},
#  {'conduitId': 'AR-NO20231012163505-P', 'arraySequence': '675'},
#  {'conduitId': 'AR-NO20231012163537-SP', 'arraySequence': '676'},
#  {'conduitId': 'AR-NO20231012163537-EP', 'arraySequence': '677'},
#  {'conduitId': 'AR-NO20231012163547-P', 'arraySequence': '678'},
#  {'conduitId': 'AR-NO20231012163555-SP', 'arraySequence': '679'},
#  {'conduitId': 'AR-NO20231012163555-EP', 'arraySequence': '680'},
#  {'conduitId': 'AR-NO20231012163603-P', 'arraySequence': '681'},
#  {'conduitId': 'AR-NO20231013100811-SP', 'arraySequence': '682'},
#  {'conduitId': 'AR-NO20231013100815-SP', 'arraySequence': '683'},
#  {'conduitId': 'AR-NO20231013100819-SP', 'arraySequence': '684'},
#  {'conduitId': 'AR-NO20231013100819-EP', 'arraySequence': '685'},
#  {'conduitId': 'AR-NO20231013100848-P', 'arraySequence': '686'},
#  {'conduitId': 'AR-NO20231013100857-P', 'arraySequence': '687'},
#  {'conduitId': 'AR-NO20231013100905-P', 'arraySequence': '688'},
#  {'conduitId': 'AR-NO20231013101031-SP', 'arraySequence': '689'},
#  {'conduitId': 'AR-NO20231013101035-SP', 'arraySequence': '690'},
#  {'conduitId': 'AR-NO20231013101045-P', 'arraySequence': '691'},
#  {'conduitId': 'AR-NO20231013101050-P', 'arraySequence': '692'},
#  {'conduitId': 'AR-NO20231013101058-SP', 'arraySequence': '693'},
#  {'conduitId': 'AR-NO20231013101101-SP', 'arraySequence': '694'},
#  {'conduitId': 'AR-NO20231013101126-P', 'arraySequence': '695'},
#  {'conduitId': 'AR-NO20231013101133-P', 'arraySequence': '696'},
#  {'conduitId': 'AR-NO20231013101146-SP', 'arraySequence': '697'},
#  {'conduitId': 'AR-NO20231013101146-EP', 'arraySequence': '698'},
#  {'conduitId': 'AR-NO20231013101148-SP', 'arraySequence': '699'},
#  {'conduitId': 'AR-NO20231013101206-P', 'arraySequence': '700'},
#  {'conduitId': 'AR-NO20231013101213-P', 'arraySequence': '701'},
#  {'conduitId': 'AR-NO20231013101222-SP', 'arraySequence': '702'},
#  {'conduitId': 'AR-NO20231013101227-SP', 'arraySequence': '703'},
#  {'conduitId': 'AR-NO20231013101227-EP', 'arraySequence': '704'},
#  {'conduitId': 'AR-NO20231013101238-P', 'arraySequence': '705'},
#  {'conduitId': 'AR-NO20231013101245-P', 'arraySequence': '706'},
#  {'conduitId': 'AR-NO20231013101259-P', 'arraySequence': '707'},
#  {'conduitId': 'AR-NO20231013101323-SP', 'arraySequence': '708'},
#  {'conduitId': 'AR-NO20231013101323-EP', 'arraySequence': '709'},
#  {'conduitId': 'AR-NO20231013101327-SP', 'arraySequence': '710'},
#  {'conduitId': 'AR-NO20231013101334-SP', 'arraySequence': '711'},
#  {'conduitId': 'AR-NO20231013101334-EP', 'arraySequence': '712'},
#  {'conduitId': 'AR-NO20231013101338-SP', 'arraySequence': '713'},
#  {'conduitId': 'AR-NO20231013101338-EP', 'arraySequence': '714'},
#  {'conduitId': 'AR-NO20231013101345-SP', 'arraySequence': '715'},
#  {'conduitId': 'AR-NO20231013101345-EP', 'arraySequence': '716'},
#  {'conduitId': 'AR-NO20231013101408-P', 'arraySequence': '717'},
#  {'conduitId': 'AR-NO20231013101415-P', 'arraySequence': '718'},
#  {'conduitId': 'AR-NO20231013101422-P', 'arraySequence': '719'},
#  {'conduitId': 'AR-NO20231013101429-P', 'arraySequence': '720'},
#  {'conduitId': 'AR-NO20231013101435-P', 'arraySequence': '721'},
#  {'conduitId': 'AR-NO20231013101443-P', 'arraySequence': '722'},
#  {'conduitId': 'AR-NO20231013101448-P', 'arraySequence': '723'},
#  {'conduitId': 'AR-NO20231013101909-SP', 'arraySequence': '724'},
#  {'conduitId': 'AR-NO20231013101909-EP', 'arraySequence': '725'},
#  {'conduitId': 'AR-NO20231013101920-SP', 'arraySequence': '726'},
#  {'conduitId': 'AR-NO20231013101920-EP', 'arraySequence': '727'},
#  {'conduitId': 'AR-NO20231013102016-P', 'arraySequence': '728'},
#  {'conduitId': 'AR-NO20231013102029-P', 'arraySequence': '729'},
#  {'conduitId': 'AR-NO20231013102042-SP', 'arraySequence': '730'},
#  {'conduitId': 'AR-NO20231013102042-EP', 'arraySequence': '731'},
#  {'conduitId': 'AR-NO20231013102050-P', 'arraySequence': '732'},
#  {'conduitId': 'AR-NO20231013102105-P', 'arraySequence': '733'},
#  {'conduitId': 'AR-NO20231013102808-SP', 'arraySequence': '734'},
#  {'conduitId': 'AR-NO20231013102808-EP', 'arraySequence': '735'},
#  {'conduitId': 'AR-NO20231013102829-P', 'arraySequence': '736'},
#  {'conduitId': 'AR-NO20231013102859-SP', 'arraySequence': '737'},
#  {'conduitId': 'AR-NO20231013102908-SP', 'arraySequence': '738'},
#  {'conduitId': 'AR-NO20231013102914-SP', 'arraySequence': '739'},
#  {'conduitId': 'AR-NO20231013102920-SP', 'arraySequence': '740'},
#  {'conduitId': 'AR-NO20231013102920-EP', 'arraySequence': '741'},
#  {'conduitId': 'AR-NO20231013102928-SP', 'arraySequence': '742'},
#  {'conduitId': 'AR-NO20231013102928-EP', 'arraySequence': '743'},
#  {'conduitId': 'AR-NO20231013103215-P', 'arraySequence': '744'},
#  {'conduitId': 'AR-NO20231013103227-P', 'arraySequence': '745'},
#  {'conduitId': 'AR-NO20231013103250-P', 'arraySequence': '746'},
#  {'conduitId': 'AR-NO20231013103305-P', 'arraySequence': '747'},
#  {'conduitId': 'AR-NO20231013103310-P', 'arraySequence': '748'},
#  {'conduitId': 'AR-NO20231013103318-P', 'arraySequence': '749'},
#  {'conduitId': 'AR-NO20231013103324-P', 'arraySequence': '750'},
#  {'conduitId': 'AR-NO20231013103329-P', 'arraySequence': '751'},
#  {'conduitId': 'AR-NO20231013103339-SP', 'arraySequence': '752'},
#  {'conduitId': 'AR-NO20231013103339-EP', 'arraySequence': '753'},
#  {'conduitId': 'AR-NO20231013103353-P', 'arraySequence': '754'},
#  {'conduitId': 'AR-NO20231013103358-P', 'arraySequence': '755'},
#  {'conduitId': 'AR-NO20231013103410-SP', 'arraySequence': '756'},
#  {'conduitId': 'AR-NO20231013103410-EP', 'arraySequence': '757'},
#  {'conduitId': 'AR-NO20231013103420-P', 'arraySequence': '758'},
#  {'conduitId': 'AR-NO20231013103427-P', 'arraySequence': '759'},
#  {'conduitId': 'AR-NO20231013103439-P', 'arraySequence': '760'},
#  {'conduitId': 'AR-NO20231013103443-P', 'arraySequence': '761'},
#  {'conduitId': 'AR-NO20231013103454-SP', 'arraySequence': '762'},
#  {'conduitId': 'AR-NO20231013103454-EP', 'arraySequence': '763'},
#  {'conduitId': 'AR-NO20231013103501-P', 'arraySequence': '764'},
#  {'conduitId': 'AR-NO20231013103508-SP', 'arraySequence': '765'},
#  {'conduitId': 'AR-NO20231013103508-EP', 'arraySequence': '766'},
#  {'conduitId': 'AR-NO20231013103512-SP', 'arraySequence': '767'},
#  {'conduitId': 'AR-NO20231013103512-EP', 'arraySequence': '768'},
#  {'conduitId': 'AR-NO20231013103518-SP', 'arraySequence': '769'},
#  {'conduitId': 'AR-NO20231013103518-EP', 'arraySequence': '770'},
#  {'conduitId': 'AR-NO20231013103522-SP', 'arraySequence': '771'},
#  {'conduitId': 'AR-NO20231013103522-EP', 'arraySequence': '772'},
#  {'conduitId': 'AR-NO20231013103531-P', 'arraySequence': '773'},
#  {'conduitId': 'AR-NO20231013103539-P', 'arraySequence': '774'},
#  {'conduitId': 'AR-NO20231013103545-P', 'arraySequence': '775'},
#  {'conduitId': 'AR-NO20231013103551-P', 'arraySequence': '776'},
#  {'conduitId': 'AR-NO20231013103556-P', 'arraySequence': '777'},
#  {'conduitId': 'AR-NO20231013103605-P', 'arraySequence': '778'},
#  {'conduitId': 'AR-NO20231013103623-SP', 'arraySequence': '779'},
#  {'conduitId': 'AR-NO20231013103623-EP', 'arraySequence': '780'},
#  {'conduitId': 'AR-NO20231013103631-P', 'arraySequence': '781'},
#  {'conduitId': 'AR-NO20231013103635-P', 'arraySequence': '782'},
#  {'conduitId': 'AR-NO20231013103909-P', 'arraySequence': '783'},
#  {'conduitId': 'AR-NO20231013103926-P', 'arraySequence': '784'},
#  {'conduitId': 'AR-NO20231013103936-SP', 'arraySequence': '785'},
#  {'conduitId': 'AR-NO20231013103936-EP', 'arraySequence': '786'},
#  {'conduitId': 'AR-NO20231013103958-P', 'arraySequence': '787'},
#  {'conduitId': 'AR-NO20231013104005-P', 'arraySequence': '788'},
#  {'conduitId': 'AR-NO20231013104011-SP', 'arraySequence': '789'},
#  {'conduitId': 'AR-NO20231013104011-EP', 'arraySequence': '790'},
#  {'conduitId': 'AR-NO20231013104018-P', 'arraySequence': '791'},
#  {'conduitId': 'AR-NO20231013104028-SP', 'arraySequence': '792'},
#  {'conduitId': 'AR-NO20231013104043-SP', 'arraySequence': '793'},
#  {'conduitId': 'AR-NO20231013104043-EP', 'arraySequence': '794'},
#  {'conduitId': 'AR-NO20231013104050-P', 'arraySequence': '795'},
#  {'conduitId': 'AR-NO20231013104056-P', 'arraySequence': '796'},
#  {'conduitId': 'AR-NO20231013104101-SP', 'arraySequence': '797'},
#  {'conduitId': 'AR-NO20231013104101-EP', 'arraySequence': '798'},
#  {'conduitId': 'AR-NO20231013104106-P', 'arraySequence': '799'},
#  {'conduitId': 'AR-NO20231013104114-P', 'arraySequence': '800'},
#  {'conduitId': 'AR-NO20231013104120-SP', 'arraySequence': '801'},
#  {'conduitId': 'AR-NO20231013104120-EP', 'arraySequence': '802'},
#  {'conduitId': 'AR-NO20231013104125-P', 'arraySequence': '803'},
#  {'conduitId': 'AR-NO20231013104131-SP', 'arraySequence': '804'},
#  {'conduitId': 'AR-NO20231013104131-EP', 'arraySequence': '805'},
#  {'conduitId': 'AR-NO20231013104138-P', 'arraySequence': '806'},
#  {'conduitId': 'AR-NO20231013104149-P', 'arraySequence': '807'},
#  {'conduitId': 'AR-NO20231013105113-SP', 'arraySequence': '808'},
#  {'conduitId': 'AR-NO20231013105113-EP', 'arraySequence': '809'},
#  {'conduitId': 'AR-NO20231013105119-P', 'arraySequence': '810'},
#  {'conduitId': 'AR-NO20231013105131-SP', 'arraySequence': '811'},
#  {'conduitId': 'AR-NO20231013105131-EP', 'arraySequence': '812'},
#  {'conduitId': 'AR-NO20231013105139-P', 'arraySequence': '813'},
#  {'conduitId': 'AR-NO20231013105149-SP', 'arraySequence': '814'},
#  {'conduitId': 'AR-NO20231013105149-EP', 'arraySequence': '815'},
#  {'conduitId': 'AR-NO20231013105154-P', 'arraySequence': '816'},
#  {'conduitId': 'AR-NO20231013105207-SP', 'arraySequence': '817'},
#  {'conduitId': 'AR-NO20231013105207-EP', 'arraySequence': '818'},
#  {'conduitId': 'AR-NO20231013105213-P', 'arraySequence': '819'},
#  {'conduitId': 'AR-NO20231013105222-SP', 'arraySequence': '820'},
#  {'conduitId': 'AR-NO20231013105222-EP', 'arraySequence': '821'},
#  {'conduitId': 'AR-NO20231013105240-P', 'arraySequence': '822'},
#  {'conduitId': 'AR-NO20231013105409-SP', 'arraySequence': '823'},
#  {'conduitId': 'AR-NO20231013105409-EP', 'arraySequence': '824'},
#  {'conduitId': 'AR-NO20231013105414-P', 'arraySequence': '825'},
#  {'conduitId': 'AR-NO20231013105419-P', 'arraySequence': '826'},
#  {'conduitId': 'AR-NO20231013105425-SP', 'arraySequence': '827'},
#  {'conduitId': 'AR-NO20231013105425-EP', 'arraySequence': '828'},
#  {'conduitId': 'AR-NO20231013105431-P', 'arraySequence': '829'},
#  {'conduitId': 'AR-NO20231013105437-P', 'arraySequence': '830'},
#  {'conduitId': 'AR-NO20231013105444-SP', 'arraySequence': '831'},
#  {'conduitId': 'AR-NO20231013105444-EP', 'arraySequence': '832'},
#  {'conduitId': 'AR-NO20231013105450-P', 'arraySequence': '833'},
#  {'conduitId': 'AR-NO20231013105454-P', 'arraySequence': '834'},
#  {'conduitId': 'AR-NO20231013105503-SP', 'arraySequence': '835'},
#  {'conduitId': 'AR-NO20231013105503-EP', 'arraySequence': '836'},
#  {'conduitId': 'AR-NO20231013105509-P', 'arraySequence': '837'},
#  {'conduitId': 'AR-NO20231013105521-SP', 'arraySequence': '838'},
#  {'conduitId': 'AR-NO20231013105526-P', 'arraySequence': '839'},
#  {'conduitId': 'AR-NO20231013105531-P', 'arraySequence': '840'},
#  {'conduitId': 'AR-NO20231013111020-SP', 'arraySequence': '841'},
#  {'conduitId': 'AR-NO20231013111020-EP', 'arraySequence': '842'},
#  {'conduitId': 'AR-NO20231013111026-P', 'arraySequence': '843'},
#  {'conduitId': 'AR-NO20231013111039-P', 'arraySequence': '844'},
#  {'conduitId': 'AR-NO20231013111045-SP', 'arraySequence': '845'},
#  {'conduitId': 'AR-NO20231013111045-EP', 'arraySequence': '846'},
#  {'conduitId': 'AR-NO20231013111049-SP', 'arraySequence': '847'},
#  {'conduitId': 'AR-NO20231013111051-SP', 'arraySequence': '848'},
#  {'conduitId': 'AR-NO20231013111051-EP', 'arraySequence': '849'},
#  {'conduitId': 'AR-NO20231013111104-SP', 'arraySequence': '850'},
#  {'conduitId': 'AR-NO20231013111104-EP', 'arraySequence': '851'},
#  {'conduitId': 'AR-NO20231013111109-SP', 'arraySequence': '852'},
#  {'conduitId': 'AR-NO20231013111109-EP', 'arraySequence': '853'},
#  {'conduitId': 'AR-NO20231013111128-P', 'arraySequence': '854'},
#  {'conduitId': 'AR-NO20231013111320-P', 'arraySequence': '855'},
#  {'conduitId': 'AR-NO20231013111326-P', 'arraySequence': '856'},
#  {'conduitId': 'AR-NO20231013111413-P', 'arraySequence': '857'},
#  {'conduitId': 'AR-NO20231013111418-P', 'arraySequence': '858'},
#  {'conduitId': 'AR-NO20231013112927-P', 'arraySequence': '859'},
#  {'conduitId': 'AR-NO20231013112941-P', 'arraySequence': '860'},
#  {'conduitId': 'AR-NO20231013112945-SP', 'arraySequence': '861'},
#  {'conduitId': 'AR-NO20231013112945-EP', 'arraySequence': '862'},
#  {'conduitId': 'AR-NO20231013112950-P', 'arraySequence': '863'},
#  {'conduitId': 'AR-NO20231013112956-P', 'arraySequence': '864'},
#  {'conduitId': 'AR-NO20231013113005-P', 'arraySequence': '865'},
#  {'conduitId': 'AR-NO20231013113013-P', 'arraySequence': '866'},
#  {'conduitId': 'AR-NO20231013113021-SP', 'arraySequence': '867'},
#  {'conduitId': 'AR-NO20231013113021-EP', 'arraySequence': '868'},
#  {'conduitId': 'AR-NO20231013113027-P', 'arraySequence': '869'},
#  {'conduitId': 'AR-NO20231013113035-P', 'arraySequence': '870'},
#  {'conduitId': 'AR-NO20231013113039-SP', 'arraySequence': '871'},
#  {'conduitId': 'AR-NO20231013113046-P', 'arraySequence': '872'},
#  {'conduitId': 'AR-NO20231013114721-SP', 'arraySequence': '873'},
#  {'conduitId': 'AR-NO20231013114727-SP', 'arraySequence': '874'},
#  {'conduitId': 'AR-NO20231013114727-EP', 'arraySequence': '875'},
#  {'conduitId': 'AR-NO20231013114747-P', 'arraySequence': '876'},
#  {'conduitId': 'AR-NO20231013114751-P', 'arraySequence': '877'},
#  {'conduitId': 'AR-NO20231013114917-SP', 'arraySequence': '878'},
#  {'conduitId': 'AR-NO20231013114919-SP', 'arraySequence': '879'},
#  {'conduitId': 'AR-NO20231013114919-EP', 'arraySequence': '880'},
#  {'conduitId': 'AR-NO20231013114922-SP', 'arraySequence': '881'},
#  {'conduitId': 'AR-NO20231013114922-EP', 'arraySequence': '882'},
#  {'conduitId': 'AR-NO20231013114927-P', 'arraySequence': '883'},
#  {'conduitId': 'AR-NO20231013114930-P', 'arraySequence': '884'},
#  {'conduitId': 'AR-NO20231013114934-P', 'arraySequence': '885'},
#  {'conduitId': 'AR-NO20231013114941-P', 'arraySequence': '886'},
#  {'conduitId': 'AR-NO20231013114944-SP', 'arraySequence': '887'},
#  {'conduitId': 'AR-NO20231013114950-P', 'arraySequence': '888'},
#  {'conduitId': 'AR-NO20231013115006-SP', 'arraySequence': '889'},
#  {'conduitId': 'AR-NO20231013115006-EP', 'arraySequence': '890'},
#  {'conduitId': 'AR-NO20231013115012-P', 'arraySequence': '891'},
#  {'conduitId': 'AR-NO20231013144338-SP', 'arraySequence': '892'},
#  {'conduitId': 'AR-NO20231013144338-EP', 'arraySequence': '893'},
#  {'conduitId': 'AR-NO20231013144352-P', 'arraySequence': '894'},
#  {'conduitId': 'AR-NO20231013144359-SP', 'arraySequence': '895'},
#  {'conduitId': 'AR-NO20231013144359-EP', 'arraySequence': '896'},
#  {'conduitId': 'AR-NO20231013144405-P', 'arraySequence': '897'},
#  {'conduitId': 'AR-NO20231013144411-SP', 'arraySequence': '898'},
#  {'conduitId': 'AR-NO20231013144411-EP', 'arraySequence': '899'},
#  {'conduitId': 'AR-NO20231013144507-P', 'arraySequence': '900'},
#  {'conduitId': 'AR-NO20231013144516-P', 'arraySequence': '901'},
#  {'conduitId': 'AR-NO20231013144626-EP', 'arraySequence': '902'},
#  {'conduitId': 'AR-NO20231013144631-P', 'arraySequence': '903'},
#  {'conduitId': 'AR-NO20231013144636-P', 'arraySequence': '904'},
#  {'conduitId': 'AR-NO20231013144641-SP', 'arraySequence': '905'},
#  {'conduitId': 'AR-NO20231013144641-EP', 'arraySequence': '906'},
#  {'conduitId': 'AR-NO20231013144645-P', 'arraySequence': '907'},
#  {'conduitId': 'AR-NO20231013144652-SP', 'arraySequence': '908'},
#  {'conduitId': 'AR-NO20231013144654-SP', 'arraySequence': '909'},
#  {'conduitId': 'AR-NO20231013144656-SP', 'arraySequence': '910'},
#  {'conduitId': 'AR-NO20231013144656-EP', 'arraySequence': '911'},
#  {'conduitId': 'AR-NO20231013144702-P', 'arraySequence': '912'},
#  {'conduitId': 'AR-NO20231013144826-P', 'arraySequence': '913'},
#  {'conduitId': 'AR-NO20231013144832-P', 'arraySequence': '914'},
#  {'conduitId': 'AR-NO20231013150146-EP', 'arraySequence': '915'},
#  {'conduitId': 'AR-NO20231013150157-P', 'arraySequence': '916'},
#  {'conduitId': 'AR-NO20231013150225-SP', 'arraySequence': '917'},
#  {'conduitId': 'AR-NO20231013150225-EP', 'arraySequence': '918'},
#  {'conduitId': 'AR-NO20231013150233-P', 'arraySequence': '919'},
#  {'conduitId': 'AR-NO20231013150239-EP', 'arraySequence': '920'},
#  {'conduitId': 'AR-NO20231013150247-P', 'arraySequence': '921'},
#  {'conduitId': 'AR-NO20231013150303-SP', 'arraySequence': '922'},
#  {'conduitId': 'AR-NO20231013150303-EP', 'arraySequence': '923'},
#  {'conduitId': 'AR-NO20231013150310-P', 'arraySequence': '924'},
#  {'conduitId': 'AR-NO20231013150318-SP', 'arraySequence': '925'},
#  {'conduitId': 'AR-NO20231013150318-EP', 'arraySequence': '926'},
#  {'conduitId': 'AR-NO20231013150324-P', 'arraySequence': '927'},
#  {'conduitId': 'AR-NO20231013150335-SP', 'arraySequence': '928'},
#  {'conduitId': 'AR-NO20231013150337-SP', 'arraySequence': '929'},
#  {'conduitId': 'AR-NO20231013150337-EP', 'arraySequence': '930'},
#  {'conduitId': 'AR-NO20231013150344-P', 'arraySequence': '931'},
#  {'conduitId': 'AR-NO20231013150348-P', 'arraySequence': '932'},
#  {'conduitId': 'AR-NO20231013150353-P', 'arraySequence': '933'},
#  {'conduitId': 'AR-NO20231013150408-P', 'arraySequence': '934'},
#  {'conduitId': 'AR-NO20231013150423-SP', 'arraySequence': '935'},
#  {'conduitId': 'AR-NO20231013150423-EP', 'arraySequence': '936'},
#  {'conduitId': 'AR-NO20231013150944-P', 'arraySequence': '937'},
#  {'conduitId': 'AR-NO20231013150955-SP', 'arraySequence': '938'},
#  {'conduitId': 'AR-NO20231013150955-EP', 'arraySequence': '939'},
#  {'conduitId': 'AR-NO20231013151047-P', 'arraySequence': '940'},
#  {'conduitId': 'AR-NO20231013151054-P', 'arraySequence': '941'},
#  {'conduitId': 'AR-NO20231013151106-P', 'arraySequence': '942'},
#  {'conduitId': 'AR-NO20231013151125-P', 'arraySequence': '943'},
#  {'conduitId': 'AR-NO20231013151130-SP', 'arraySequence': '944'},
#  {'conduitId': 'AR-NO20231013151130-EP', 'arraySequence': '945'},
#  {'conduitId': 'AR-NO20231013151137-P', 'arraySequence': '946'},
#  {'conduitId': 'AR-NO20231013151145-SP', 'arraySequence': '947'},
#  {'conduitId': 'AR-NO20231013151145-EP', 'arraySequence': '948'},
#  {'conduitId': 'AR-NO20231013151155-P', 'arraySequence': '949'},
#  {'conduitId': 'AR-NO20231013151202-SP', 'arraySequence': '950'},
#  {'conduitId': 'AR-NO20231013151204-SP', 'arraySequence': '951'},
#  {'conduitId': 'AR-NO20231013151204-EP', 'arraySequence': '952'},
#  {'conduitId': 'AR-NO20231013151208-SP', 'arraySequence': '953'},
#  {'conduitId': 'AR-NO20231013151208-EP', 'arraySequence': '954'},
#  {'conduitId': 'AR-NO20231013151215-P', 'arraySequence': '955'},
#  {'conduitId': 'AR-NO20231013151220-P', 'arraySequence': '956'},
#  {'conduitId': 'AR-NO20231013151228-P', 'arraySequence': '957'},
#  {'conduitId': 'AR-NO20231013151236-SP', 'arraySequence': '958'},
#  {'conduitId': 'AR-NO20231013151236-EP', 'arraySequence': '959'},
#  {'conduitId': 'AR-NO20231013151255-SP', 'arraySequence': '960'},
#  {'conduitId': 'AR-NO20231013151259-SP', 'arraySequence': '961'},
#  {'conduitId': 'AR-NO20231013151259-EP', 'arraySequence': '962'},
#  {'conduitId': 'AR-NO20231013151305-P', 'arraySequence': '963'},
#  {'conduitId': 'AR-NO20231013151309-P', 'arraySequence': '964'},
#  {'conduitId': 'AR-NO20231013151406-SP', 'arraySequence': '965'},
#  {'conduitId': 'AR-NO20231013151406-EP', 'arraySequence': '966'},
#  {'conduitId': 'AR-NO20231013151411-SP', 'arraySequence': '967'},
#  {'conduitId': 'AR-NO20231013151411-EP', 'arraySequence': '968'},
#  {'conduitId': 'AR-NO20231013151418-SP', 'arraySequence': '969'},
#  {'conduitId': 'AR-NO20231013151418-EP', 'arraySequence': '970'},
#  {'conduitId': 'AR-NO20231013151459-P', 'arraySequence': '971'},
#  {'conduitId': 'AR-NO20231013151503-P', 'arraySequence': '972'},
#  {'conduitId': 'AR-NO20231013151510-P', 'arraySequence': '973'},
#  {'conduitId': 'AR-NO20231013151520-P', 'arraySequence': '974'},
#  {'conduitId': 'AR-NO20231013151526-P', 'arraySequence': '975'},
#  {'conduitId': 'AR-NO20231013151531-P', 'arraySequence': '976'},
#  {'conduitId': 'AR-NO20231013151542-SP', 'arraySequence': '977'},
#  {'conduitId': 'AR-NO20231013151545-SP', 'arraySequence': '978'},
#  {'conduitId': 'AR-NO20231013151547-SP', 'arraySequence': '979'},
#  {'conduitId': 'AR-NO20231013151547-EP', 'arraySequence': '980'},
#  {'conduitId': 'AR-NO20231013151553-P', 'arraySequence': '981'},
#  {'conduitId': 'AR-NO20231013151558-P', 'arraySequence': '982'},
#  {'conduitId': 'AR-NO20231013151641-SP', 'arraySequence': '983'},
#  {'conduitId': 'AR-NO20231013151641-EP', 'arraySequence': '984'},
#  {'conduitId': 'AR-NO20231013151646-P', 'arraySequence': '985'},
#  {'conduitId': 'AR-NO20231013151655-SP', 'arraySequence': '986'},
#  {'conduitId': 'AR-NO20231013151655-EP', 'arraySequence': '987'},
#  {'conduitId': 'AR-NO20231013151658-SP', 'arraySequence': '988'},
#  {'conduitId': 'AR-NO20231013151701-SP', 'arraySequence': '989'},
#  {'conduitId': 'AR-NO20231013151701-EP', 'arraySequence': '990'},
#  {'conduitId': 'AR-NO20231013151707-SP', 'arraySequence': '991'},
#  {'conduitId': 'AR-NO20231013151709-SP', 'arraySequence': '992'},
#  {'conduitId': 'AR-NO20231013151709-EP', 'arraySequence': '993'},
#  {'conduitId': 'AR-NO20231013151720-P', 'arraySequence': '994'},
#  {'conduitId': 'AR-NO20231013151725-P', 'arraySequence': '995'},
#  {'conduitId': 'AR-NO20231013151729-P', 'arraySequence': '996'},
#  {'conduitId': 'AR-NO20231013151737-P', 'arraySequence': '997'},
#  {'conduitId': 'AR-NO20231013151741-P', 'arraySequence': '998'},
#  {'conduitId': 'AR-NO20231013151745-P', 'arraySequence': '999'},
#  ...]

# %% [markdown]
# ## 5. 数据关联

# %%
# ======= 3) 关联（以 JSON 为主，LEFT JOIN shp） =======
merged = json_df.merge(shp_df, left_on="id", right_on=SHP_ID_COL, how="left")
merged = merged.drop(columns=[SHP_ID_COL]).rename(columns={SHP_SYS_COL: "systemtype"})

# %% [markdown]
# ## 6. 数据质量检查

# %%
# ======= 4) 质量检查 =======
not_matched = merged[merged["systemtype"].isna()]
print(f"[INFO] JSON 中序号总数：{len(json_df)}")
print(f"[INFO] 成功匹配到 shp 的条数：{len(merged) - len(not_matched)}")
print(f"[INFO] 未匹配到 shp 的条数：{len(not_matched)}")

# 同一 id 在 shp 是否重复（可能导致一个 seq 对应多个 systemtype）
dup_id = shp_df[shp_df.duplicated(subset=[SHP_ID_COL], keep=False)].sort_values(SHP_ID_COL)
if not dup_id.empty:
    print("[WARN] 下列 id 在 shp 中出现多次（示例前 10 行）：")
    print(dup_id.head(10))
# Out:
# [INFO] JSON 中序号总数：247810
# [INFO] 成功匹配到 shp 的条数：233344
# [INFO] 未匹配到 shp 的条数：11972
# [WARN] 下列 id 在 shp 中出现多次（示例前 10 行）：
#            asset_id systemtype
# 240627  ADDED_21004      storm
# 144816  ADDED_21004   combined
# 217772   AGDYS_0006      storm
# 217771   AGDYS_0006      storm
# 241331      B006367       foul
# 241311      B006367       foul
# 217755      B011463       foul
# 241032      B011463       foul
# 241033      B011463       foul
# 241068      Des_380      storm

# %% [markdown]
# ## 7. 生成映射表（CSV）

# %%
seq2types = (merged.dropna(subset=["systemtype"])
                   .groupby("seq")["systemtype"]
                   .agg(lambda s: sorted(set(s)))
                   .reset_index())
seq2types_path = str(Path(OUTPUT_DIR, "seq_to_systemtypes.csv"))
seq2types.to_csv(seq2types_path, index=False, encoding="utf-8-sig")
print(f"[DONE] 序号→systemtype 映射：{seq2types_path}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 6
#       1 seq2types = (merged.dropna(subset=["systemtype"])
#       2                    .groupby("seq")["systemtype"]
#       3                    .agg(lambda s: sorted(set(s)))
#       4                    .reset_index())
#       5 seq2types_path = str(Path(OUTPUT_DIR, "seq_to_systemtypes.csv"))
# ----> 6 seq2types.to_csv(seq2types_path, index=False, encoding="utf-8-sig")
#       7 print(f"[DONE] 序号→systemtype 映射：{seq2types_path}")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'F:\beipai\管井\管线管井序号编码\node_out'

# %% [markdown]
# ## 8. 转换为 Python 字典

# %%
import json
from pathlib import Path


# 还是在你已有 seq2types 之后执行
seq2types = (
    merged.dropna(subset=["systemtype"])
          .groupby("seq")["systemtype"]
          .agg(lambda s: sorted(set(s)))
          .reset_index()
)

# 转为 Python dict：{seq: systemtype或[systemtype1, systemtype2,...]}
seq2types_dict = {}
for _, row in seq2types.iterrows():
    seq = int(row["seq"]) if str(row["seq"]).isdigit() else str(row["seq"])
    systems = row["systemtype"]
    # 如果只有一个元素，就直接取字符串而不是列表
    if isinstance(systems, (list, tuple)) and len(systems) == 1:
        seq2types_dict[seq] = systems[0]
    else:
        seq2types_dict[seq] = systems

# %% [markdown]
# ## 9. 导出为 JSON 文件

# %%
# 导出为 JSON 文件
seq2types_path = Path(OUTPUT_DIR) / "links.json"
with open(seq2types_path, "w", encoding="utf-8") as f:
    json.dump(seq2types_dict, f, ensure_ascii=False, indent=2)

print(f"[DONE] 已导出 JSON 文件：{seq2types_path}")
# Out:
# [DONE] 已导出 JSON 文件：F:\beipai\管井\管线管井序号编码\links_out\links.json
